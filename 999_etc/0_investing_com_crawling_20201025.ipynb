# %% [markdown]
# # Investing.com 크롤러 만들기

# %% [markdown]
# 동생이 [Investing.com](https://www.investing.com/equities/) 에서 S&P 500 기업들의 정보를 크롤링 하는 것을 만들고 있길래 도와 줄 겸 나도 한번 해 보았다.

# %% [markdown]
# ## 하고자 하는 것
# 1.   [S&P 500 기업 리스트](https://kr.investing.com/equities/StocksFilter?noconstruct=1&smlID=595&sid=&tabletype=price&index_id=166)를 받아온다
# 2.   각 기업 별 정보 페이지에서 원하는 정보를 추출해낸다.

# %% [markdown]
# ## 사전 작업
# ### Library Import
# 일단 크롤링을 위해 requests 및 BeautifulSoup을 쓸 것이다. 두 개를 Import 하자

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### User Agent 설정
# investing.com 은 하나의 User Agent에서 반복하여 요청을 하면 올바르지 않는 접근으로 간주하여 접속을 거부한다. 이를 위해 User Agent 리스트를 정의하고, 매 요청마다 임의의 User Agent를 선택하여 요청하자.

# %%
import random
USER_AGENTS = [
    "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.5; en-US; rv:1.9.1b3) Gecko/20090305 Firefox/3.1b3 GTB5",
    "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.5; ko; rv:1.9.1b2) Gecko/20081201 Firefox/3.1b2",
    "Mozilla/5.0 (X11; U; SunOS sun4u; en-US; rv:1.9b5) Gecko/2008032620 Firefox/3.0b5",
    "Mozilla/5.0 (X11; U; Linux x86_64; en-US; rv:1.8.1.12) Gecko/20080214 Firefox/2.0.0.12",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; cs; rv:1.9.0.8) Gecko/2009032609 Firefox/3.0.8",
    "Mozilla/5.0 (X11; U; OpenBSD i386; en-US; rv:1.8.0.5) Gecko/20060819 Firefox/1.5.0.5",
    "Mozilla/5.0 (Windows; U; Windows NT 5.0; es-ES; rv:1.8.0.3) Gecko/20060426 Firefox/1.5.0.3",
    "Mozilla/5.0 (Windows; U; WinNT4.0; en-US; rv:1.7.9) Gecko/20050711 Firefox/1.0.5",
    "Mozilla/5.0 (Windows; Windows NT 6.1; rv:2.0b2) Gecko/20100720 Firefox/4.0b2",
    "Mozilla/5.0 (X11; Linux x86_64; rv:2.0b4) Gecko/20100818 Firefox/4.0b4",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.2) Gecko/20100308 Ubuntu/10.04 (lucid) Firefox/3.6 GTB7.1",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:2.0b7) Gecko/20101111 Firefox/4.0b7",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:2.0b8pre) Gecko/20101114 Firefox/4.0b8pre",
    "Mozilla/5.0 (X11; Linux x86_64; rv:2.0b9pre) Gecko/20110111 Firefox/4.0b9pre",
    "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:2.0b9pre) Gecko/20101228 Firefox/4.0b9pre",
    "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:2.2a1pre) Gecko/20110324 Firefox/4.2a1pre",
    "Mozilla/5.0 (X11; U; Linux amd64; rv:5.0) Gecko/20100101 Firefox/5.0 (Debian)",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:6.0a2) Gecko/20110613 Firefox/6.0a2",
    "Mozilla/5.0 (X11; Linux i686 on x86_64; rv:12.0) Gecko/20100101 Firefox/12.0",
    "Mozilla/5.0 (Windows NT 6.1; rv:15.0) Gecko/20120716 Firefox/15.0a2",
    "Mozilla/5.0 (X11; Ubuntu; Linux armv7l; rv:17.0) Gecko/20100101 Firefox/17.0",
    "Mozilla/5.0 (Windows NT 6.1; rv:21.0) Gecko/20130328 Firefox/21.0",
    "Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:22.0) Gecko/20130328 Firefox/22.0",
    "Mozilla/5.0 (Windows NT 5.1; rv:25.0) Gecko/20100101 Firefox/25.0",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.8; rv:25.0) Gecko/20100101 Firefox/25.0",
    "Mozilla/5.0 (Windows NT 6.1; rv:28.0) Gecko/20100101 Firefox/28.0",
    "Mozilla/5.0 (X11; Linux i686; rv:30.0) Gecko/20100101 Firefox/30.0",
    "Mozilla/5.0 (Windows NT 5.1; rv:31.0) Gecko/20100101 Firefox/31.0",
    "Mozilla/5.0 (Windows NT 6.1; WOW64; rv:33.0) Gecko/20100101 Firefox/33.0",
    "Mozilla/5.0 (Windows NT 10.0; WOW64; rv:40.0) Gecko/20100101 Firefox/40.0",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.12; rv:58.0) Gecko/20100101 Firefox/58.0",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/525.19 (KHTML, like Gecko) Chrome/1.0.154.53 Safari/525.19",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/525.19 (KHTML, like Gecko) Chrome/1.0.154.36 Safari/525.19",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/7.0.540.0 Safari/534.10",
    "Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/534.4 (KHTML, like Gecko) Chrome/6.0.481.0 Safari/534.4",
    "Mozilla/5.0 (Macintosh; U; Intel Mac OS X; en-US) AppleWebKit/533.4 (KHTML, like Gecko) Chrome/5.0.375.86 Safari/533.4",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/532.2 (KHTML, like Gecko) Chrome/4.0.223.3 Safari/532.2",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/4.0.201.1 Safari/532.0",
    "Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/3.0.195.27 Safari/532.0",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/530.5 (KHTML, like Gecko) Chrome/2.0.173.1 Safari/530.5",
    "Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/8.0.558.0 Safari/534.10",
    "Mozilla/5.0 (X11; U; Linux x86_64; en-US) AppleWebKit/540.0 (KHTML,like Gecko) Chrome/9.1.0.0 Safari/540.0",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/534.14 (KHTML, like Gecko) Chrome/9.0.600.0 Safari/534.14",
    "Mozilla/5.0 (X11; U; Windows NT 6; en-US) AppleWebKit/534.12 (KHTML, like Gecko) Chrome/9.0.587.0 Safari/534.12",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.13 (KHTML, like Gecko) Chrome/9.0.597.0 Safari/534.13",
    "Mozilla/5.0 (Windows; U; Windows NT 6.1; en-US) AppleWebKit/534.16 (KHTML, like Gecko) Chrome/10.0.648.11 Safari/534.16",
    "Mozilla/5.0 (Windows; U; Windows NT 6.0; en-US) AppleWebKit/534.20 (KHTML, like Gecko) Chrome/11.0.672.2 Safari/534.20",
    "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.792.0 Safari/535.1",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/15.0.872.0 Safari/535.2",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.36 Safari/535.7",
    "Mozilla/5.0 (Windows NT 6.0; WOW64) AppleWebKit/535.11 (KHTML, like Gecko) Chrome/17.0.963.66 Safari/535.11",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.45 Safari/535.19",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/535.24 (KHTML, like Gecko) Chrome/19.0.1055.1 Safari/535.24",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/536.6 (KHTML, like Gecko) Chrome/20.0.1090.0 Safari/536.6",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.1 (KHTML, like Gecko) Chrome/22.0.1207.1 Safari/537.1",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.15 (KHTML, like Gecko) Chrome/24.0.1295.0 Safari/537.15",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1467.0 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/30.0.1599.101 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/31.0.1623.0 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/34.0.1847.116 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36",
    "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/40.0.2214.38 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/46.0.2490.71 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36",
    "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/62.0.3202.62 Safari/537.36"
]
def random_user_agent():
    return str(random.choice(USER_AGENTS))

# %% [markdown]
# *random_user_agent* 함수는 USER_AGENTS 리스트에서 임의의 user agent를 선택하는 함수이다. USER_AGENT 함수는 [investpy](https://pypi.org/project/investpy/) 라이브러리에서 가져왔다.

# %% [markdown]
# ## S&P 500 기업 리스트 추출
# 일단 S&P 500 기업 리스트 및 각 기업별 정보를 보여주는 페이지들의 HTML 소스를 모두 읽어오자.

# %%
import re
def get_snp500_link_list():
  # 크롤링 할 페이지 주소
  url_snp500list = "https://kr.investing.com/equities/StocksFilter?noconstruct=1&smlID=595&sid=&tabletype=price&index_id=166"

  # Request Header 설정. User agent는 매번 임의로 선택한다.
  head = {
      "User-Agent": random_user_agent(),
      "X-Requested-With": "XMLHttpRequest",
      "Accept": "text/html",
      "Accept-Encoding": "gzip, deflate, br",
      "Connection": "keep-alive",
  }

  # HTML 정보를 읽어온다.
  url = url_snp500list
  response = requests.get(url, headers = head)
  soup = BeautifulSoup(response.content, "html.parser")

  # HTML을 파싱하여 S&P 500 리스트의 각 항목들을 추출한다.
  items = soup.select("#cross_rate_markets_stocks_1 tbody")[0].find_all("tr")

  # S&P 500 기업들의 정보 페이들에 대한 URL 및 기업 이름 추출하여 result 리스트에 저장한다.
  result = []

  base_url = "https://kr.investing.com"
  pattern = "equities\/.+$"
  for item in items:
    company = {}
    link = item.find_all("td")[1].find_all("a")[0]
    # 기업 정보페이지의 URL에서 정규식으로 기업 이름에 대한 부분만 추출해낸다.
    # 예를 들어, 보잉 사의 주소인 'https://kr.investing.com/equities/boeing-co' 에서 
    # boeing-co 부분만 추출해 낸  후
    companyname=re.findall(pattern,link.attrs['href'])[0][9:]
    # 끝에 -finalcial-summary 라는 텍스트를 붙여 원하는 주소를 완성한다.
    link = base_url + link.attrs['href'] + "-financial-summary"
    company["companyname"] = companyname
    company["link"] = link    
    result.append(company)
  return result

# %%
snp500_link_list = get_snp500_link_list()

# %%
print(snp500_link_list)
# Out:
# [{'companyname': 'boeing-co', 'link': 'https://kr.investing.com/equities/boeing-co-financial-summary'}, {'companyname': 'gen-motors', 'link': 'https://kr.investing.com/equities/gen-motors-financial-summary'}, {'companyname': 'chevron', 'link': 'https://kr.investing.com/equities/chevron-financial-summary'}, {'companyname': 'citigroup', 'link': 'https://kr.investing.com/equities/citigroup-financial-summary'}, {'companyname': 'bank-of-america', 'link': 'https://kr.investing.com/equities/bank-of-america-financial-summary'}, {'companyname': 'at-t', 'link': 'https://kr.investing.com/equities/at-t-financial-summary'}, {'companyname': 'caterpillar', 'link': 'https://kr.investing.com/equities/caterpillar-financial-summary'}, {'companyname': 'intel-corp', 'link': 'https://kr.investing.com/equities/intel-corp-financial-summary'}, {'companyname': 'microsoft-corp', 'link': 'https://kr.investing.com/equities/microsoft-corp-financial-summary'}, {'companyname': 'ford-motor-co', 'link': 'https://kr.investing.com/equities/ford-motor-co-financial-summary'}, {'companyname': 'ebay-inc', 'link': 'https://kr.investing.com/equities/ebay-inc-financial-summary'}, {'companyname': 'disney', 'link': 'https://kr.investing.com/equities/disney-financial-summary'}, {'companyname': 'dow-chemical', 'link': 'https://kr.investing.com/equities/dow-chemical-financial-summary'}, {'companyname': 'cisco-sys-inc', 'link': 'https://kr.investing.com/equities/cisco-sys-inc-financial-summary'}, {'companyname': 'deere---co', 'link': 'https://kr.investing.com/equities/deere---co-financial-summary'}, {'companyname': 'fedex-corp', 'link': 'https://kr.investing.com/equities/fedex-corp-financial-summary'}, {'companyname': 'general-mills', 'link': 'https://kr.investing.com/equities/general-mills-financial-summary'}, {'companyname': 'corning-inc', 'link': 'https://kr.investing.com/equities/corning-inc-financial-summary'}, {'companyname': 'goldman-sachs-group', 'link': 'https://kr.investing.com/equities/goldman-sachs-group-financial-summary'}, {'companyname': 'jp-morgan-chase', 'link': 'https://kr.investing.com/equities/jp-morgan-chase-financial-summary'}, {'companyname': 'kimberly-clark', 'link': 'https://kr.investing.com/equities/kimberly-clark-financial-summary'}, {'companyname': 'kraft-foods-inc', 'link': 'https://kr.investing.com/equities/kraft-foods-inc-financial-summary'}, {'companyname': 'coca-cola-co', 'link': 'https://kr.investing.com/equities/coca-cola-co-financial-summary'}, {'companyname': 'mcdonalds', 'link': 'https://kr.investing.com/equities/mcdonalds-financial-summary'}, {'companyname': 'eli-lilly-and-co', 'link': 'https://kr.investing.com/equities/eli-lilly-and-co-financial-summary'}, {'companyname': 'oracle-corp', 'link': 'https://kr.investing.com/equities/oracle-corp-financial-summary'}, {'companyname': 'merck---co', 'link': 'https://kr.investing.com/equities/merck---co-financial-summary'}, {'companyname': 'motorola-inc', 'link': 'https://kr.investing.com/equities/motorola-inc-financial-summary'}, {'companyname': '3m-co', 'link': 'https://kr.investing.com/equities/3m-co-financial-summary'}, {'companyname': 'vertex-pharm', 'link': 'https://kr.investing.com/equities/vertex-pharm-financial-summary'}, {'companyname': 'monster-beverage', 'link': 'https://kr.investing.com/equities/monster-beverage-financial-summary'}, {'companyname': 'fifth-third-bk', 'link': 'https://kr.investing.com/equities/fifth-third-bk-financial-summary'}, {'companyname': 'cintas-corp', 'link': 'https://kr.investing.com/equities/cintas-corp-financial-summary'}, {'companyname': 'autodesk-inc', 'link': 'https://kr.investing.com/equities/autodesk-inc-financial-summary'}, {'companyname': 'dish-network', 'link': 'https://kr.investing.com/equities/dish-network-financial-summary'}, {'companyname': 'gilead-sciences-inc', 'link': 'https://kr.investing.com/equities/gilead-sciences-inc-financial-summary'}, {'companyname': 'google-inc', 'link': 'https://kr.investing.com/equities/google-inc-financial-summary ...

# %% [markdown]
# ## 각 기업 별 HTML 내용들을 파일로 저장하기
# 파싱 작업은 시행착오가 많이 들기 때문에 오류가 날 때 마다 수정 된 내용을 테스트 하기 위해 사이트에 접속하는것은 비효율적이다. 이 때문에 일단 원하는 페이지들을 모두 파일로 저장하자.

# %% [markdown]
# ### 구글 드라이브 설정
# 여기서는 Google Colaboratory을 이용하고 있기 때문에 파일로 저장한 내용들을 구글 드라이브에 저장할 것이다. 우선 구글 드라이브를 마운트하자.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
# 구글 드라이브는 /content/gdrive/My Drive에 마운트 되었다.
# snp500_page라는 폴더를 만들자.
page_save_dir = '/content/gdrive/My Drive/snp500_page'
os.mkdir(page_save_dir)

# %%
# 각 회사 정보 페이지의 html을 파일로 저장
def save_company_page(company,number = None):
  # 파일 정렬을 편하게 하기 위해 파일 명 앞에 번호를 붙일 수 있도록 정의
  if number != None:
    filename = page_save_dir + "/" + str(number) + "_" + company["companyname"] + ".txt"
  else:
    filename = page_save_dir + "/" + company["companyname"] + ".txt"
    
  # 파일을 연 후
  with open(filename, "w") as file:
    result = {}
    # 역시 임의의 user_agent로 요청을 날리도록 헤더를 설정하고
    head = {
        "User-Agent": random_user_agent(),
        "X-Requested-With": "XMLHttpRequest",
        "Accept": "text/html",
        "Accept-Encoding": "gzip, deflate, br",
        "Connection": "keep-alive",
    }
    
    # 요청에 대한 Response를 모두 파일로 저장한다.
    response = requests.get(company["link"], headers = head)
    file.write(response.text)

# %%
import time
pausetime = 3 # 3 초
# 읽어들여온 S&P 500 리스트에 대한 URL에 접속하여 HTML 파일을 저장한다.
for idx in range(len(snp500_link_list)):
  company = snp500_link_list[idx]
  save_company_page(company,idx)
  # 너무 빨리 요청을 하면 접속 거부가 일어나기 때문에 pausetime 만큼 잠시 멈춘 후 요청을 한다. 여기서는 3초정도 딜레이를 주었다.
  time.sleep(pausetime)

# %% [markdown]
# ## 각 페이지 파싱
# 이제 각 기업 별 정보 페이지들에 대한 HTML 파일을 모두 파이로 저장했으니 각 파일들을 파싱하여 저장하자.
# 참고로, [린드](https://kr.investing.com/equities/linde-plc?cid=942017) 라는 기업은 주소체계가 특이하게 되어 있다. https://kr.investing.com/equities/linde-plc?cid=942017 처럼 끝에 ?cid=942017이 붙어 있어 이 기업은 그냥 수동으로 HTML 파일을 긁어 왔다.

# %%
#파일을 읽어 파싱한다.
def get_company_info_from_file(file):
  result = {}
  # HTML 파일을 연다.
  with open(file, 'r') as f:
    contents = f.read()  
    soup = BeautifulSoup(contents, "html.parser")

    header_tag = soup.select("#leftColumn div h1")[0]
    company_name = header_tag.get_text().strip()
    pattern = r"\(.*\)"
    symbol = re.findall(pattern,company_name)[0][1:-1]
    result['company_name'] = company_name 
    result['symbol'] = symbol

    # 원하는 정보가 있는 테이블에 대해 원하는 형태의 dict을 만들어 낸다.
    info_tags = soup.select("#rsdiv")[0].find_all(attrs={'class':'genTbl openTbl companyFinancialSummaryTbl'})[0].select("tbody tr")  
    for info in info_tags:
      contents = info.find_all("td")
      name=contents[0].get_text()
      contents = contents[1:]
      data = []
      for content in contents:
        data.append(content.get_text())
      if name == "총수익":
        result["total_income"] = data
      elif name == "총 이익":
        result["total_margine"] = data
      elif name == "영업 이익":
        result["salse_margin"] = data
      elif name == "순이익":
        result["pure_margin"] = data 
  return result

# %%
result = []
# HTML 파일이 저장된 폴더의 모든 파일들을 순환하며 정보를 얻어낸 후 result 리스트에 넣는다.
for root, dirs, files in os.walk(page_save_dir):
  for file in files:
    filepath = page_save_dir + "/" + file
    info = get_company_info_from_file(filepath)
    result.append(info)

# %%
for data in result:
  print(data)
# Out:
# {'company_name': 'Boeing Co (BA)', 'symbol': 'BA', 'total_income': ['11807', '16908', '20560', '19980'], 'total_margine': ['-1171', '140', '1852', '3050'], 'salse_margin': ['-2964', '-1353', '-2204', '1259'], 'pure_margin': ['-2376', '-628', '-1010', '1167']}
# {'company_name': '제너럴 모터스 (GM)', 'symbol': 'GM', 'total_income': ['16778', '32709', '30826', '35473'], 'total_margine': ['996', '2627', '1728', '4312'], 'salse_margin': ['-1214', '657', '-554', '2304'], 'pure_margin': ['-758', '294', '-194', '2351']}
# {'company_name': '셰브론 (CVX)', 'symbol': 'CVX', 'total_income': ['16142', '29244', '34676', '34724'], 'total_margine': ['7998', '13739', '14984', '14849'], 'salse_margin': ['-7595', '2983', '-8565', '3147'], 'pure_margin': ['-8270', '3599', '-6610', '2580']}
# {'company_name': '씨티그룹 (C)', 'symbol': 'C', 'total_income': ['20119', '23283', '26378', '24926'], 'pure_margin': ['3230', '1316', '2522', '4979']}
# {'company_name': '뱅크오브아메리카 (BAC)', 'symbol': 'BAC', 'total_income': ['21693', '24018', '26735', '27135'], 'pure_margin': ['4881', '3533', '4010', '6994']}
# {'company_name': 'AT&T (T)', 'symbol': 'T', 'total_income': ['42340', '40950', '42779', '46821'], 'total_margine': ['22501', '22967', '23498', '24085'], 'salse_margin': ['6132', '3532', '7486', '5321'], 'pure_margin': ['2816', '1281', '4610', '2394']}
# {'company_name': '캐터필러 (CAT)', 'symbol': 'CAT', 'total_income': ['9997', '10635', '13144', '12758'], 'total_margine': ['2892', '3385', '4039', '4202'], 'salse_margin': ['784', '1404', '1850', '2020'], 'pure_margin': ['458', '1092', '1098', '1494']}
# {'company_name': '인텔 (INTC)', 'symbol': 'INTC', 'total_income': ['19728', '19828', '20209', '19190'], 'total_margine': ['10507', '12016', '11878', '11295'], 'salse_margin': ['5697', '7038', '6797', '6447'], 'pure_margin': ['5105', '5661', '6905', '5990']}
# {'company_name': '마이크로소프트 (MSFT)', 'symbol': 'MSFT', 'total_income': ['38033', '35021', '36906', '33055'], 'total_margine': ['25694', '24046', '24548', '22649'], 'salse_margin': ['13386', '12899', '13881', '12660'], 'pure_margin': ['11202', '10752', '11649', '10678']}
# {'company_name': '포드 (F)', 'symbol': 'F', 'total_income': ['19371', '34320', '39715', '36990'], 'total_margine': ['-779', '877', '2540', '3139'], 'salse_margin': ['-2760', '-1558', '-458', '-262'], 'pure_margin': ['1117', '-1993', '-1672', '425']}
# {'company_name': '이베이 (EBAY)', 'symbol': 'EBAY', 'total_income': ['2865', '2374', '2821', '2649'], 'total_margine': ['2267', '1848', '2171', '2022'], 'salse_margin': ['821', '629', '619', '532'], 'pure_margin': ['746', '3412', '556', '310']}
# {'company_name': '월트 디즈니 (DIS)', 'symbol': 'DIS', 'total_income': ['11779', '18009', '20858', '19100'], 'total_margine': ['3883', '6091', '7842', '7278'], 'salse_margin': ['-4996', '1225', '2691', '1460'], 'pure_margin': ['-4721', '460', '2107', '1054']}
# {'company_name': '다우 (DOW)', 'symbol': 'DOW', 'total_income': ['9712', '8354', '9770', '10204'], 'total_margine': ['1341', '750', '1536', '1486'], 'salse_margin': ['-4', '59', '762', '-2068'], 'pure_margin': ['-25', '-225', '239', '-2323']}
# {'company_name': '시스코 시스템즈 (CSCO)', 'symbol': 'CSCO', 'total_income': ['12154', '11983', '12005', '13159'], 'total_margine': ['7684', '7771', '7764', '8464'], 'salse_margin': ['3247', '3414', '3380', '3579'], 'pure_margin': ['2636', '2774', '2878', '2926']}
# {'company_name': '디어 (DE)', 'symbol': 'DE', 'total_income': ['8925', '9273', '7635', '9896'], 'total_margine': ['2711', '2440', '2133', '2653'], 'salse_margin': ['1560', '1034', '899', '1221'], 'pure_margin': ['811', '666', '517', '721']}
# {'company_name': '페덱스 (FDX)', 'symbol': 'FDX', 'total_income': ['19321', '17358', '17487', '17324'], 'total_margine': ['13779', '12289', '12050', '12106'], 'salse_margin': ['1590', '475', '411', '554'], 'pure_margin': ['1245', '-334', '315', '560']}
# {'company_name': '제너럴 밀스 (GIS)', 'symbol': 'GIS', 'total_income': ['4364', '5023', '4180.3', '4420.8'], 'total_margine': ['1590.9', '1770', '1410.2', '1581.4'], 'salse_margin': ['887', '851.6', '681.1', '841.4'], 'pure_margin': ['638.9', '625.7', '454.1', '580.8']}
# {'company_name': '코닝 (GLW)', 'symbol': 'GLW', 'total_income': ['2561', '2391', '2817', '2934'], 'total_margine': ['756', '561', '854', '1017'], 'salse_margin': ['-103', '-121', '147', '365'], 'pure_margin': ['-71', '-96', '32', '337']}
# {'company_name': '골드만 삭스 그룹 (GS)', 'symbol': 'GS', 'total_income': ['12629', '15385', '12180', '14141'], 'total_margine': ['9870', '12350', '7768', '9470'], 'salse_margin': ['4549', '1291', '1348', '2321'], 'pure_margin': ['3617', '373', '1213', '1917']}
# {'company_name': '제이피모건체이스 (JPM)', 'symbol': 'JPM', 'total_income': ['30834', '35239', '32973', '34092'], 'pure_margin': ['9443', '4687', '2865', '8520']}
# {'company_name': '킴벌리클라크 (KMB)', 'symbol': 'KMB', 'total_income': ['4683', '4612', '5009', '4583'], 'total_margine': ['1697', '1837', '1861', '1651'], 'salse_margin': ['692', '925', '904', '706'], 'pure_margin': ['472', '681', '660', '547']}
# {'company_name': '크래프트 하인즈 (KHC)', 'symbol': 'KHC', 'total_income': ['6648', '6157', '6536', '6076'], 'total_margine': ['2450', '1859', '2128', '1959'], 'salse_margin': ['-1339', '768', '588', '1180'], 'pure_margin': ['-1651', '378', '182', '899']}
# {'company_name': '코카콜라 (KO)', 'symbol': 'KO', 'total_income': ['8652', '7150', '8601', '9068'], 'total_margine': ['5181', '4137', '5230', '5502'], 'salse_margin': ['2283', '1924', '3300', '2242'], 'pure_margin': ['1737', '1779', '2775', '2042']}
# {'company_name': '맥도날드 (MCD)', 'symbol': 'MCD', 'total_income': ['3761.5', '4714.4', '5349', '5430.6'], 'total_margine': ['1725.3', '2341.9', '2846.1', '2903.4'], 'salse_margin': ['961.1', '1693.6', '2292.6', '2409.3'], 'pure_margin': ['483.8', '1106.9', '1572.2', '1607.9']}
# {'company_name': '일라이릴리 (LLY)', 'symbol': 'LLY', 'total_income': ['5499.4', '5859.8', '6114', '5476.6'], 'total_margine': ['4277.4', '4644.7', '4831.4', '4301.6'], 'salse_margin': ['1196.8', '1590.8', '1457.5', '1430.7'], 'pure_margin': ['1412', '1456.5', '1495.7', '1253.9']}
# {'company_name': '오라클 (ORCL)', 'symbol': 'ORCL', 'total_income': ['9367', '10439', '9796', '9614'], 'total_margine': ['7487', '8470', '7832', '7566'], 'salse_margin': ['3211', '4308', '3528', '3183'], 'pure_margin': ['2251', '3116', '2571', '2311']}
# {'company_name': '머크앤드컴퍼니 (MRK)', 'symbol': 'MRK', 'total_income': ['10872', '12057', '11868', '12397'], 'total_margine': ['7738', '8813', '8994', '8469'], 'salse_margin': ['3129', '3909', '2568', '2382'], 'pure_margin': ['3002', '3219', '2356', '1901']}
# {'company_name': '모토롤라 (MSI)', 'symbol': 'MSI', 'total_income': ['1618', '1655', '2376', '1994'], 'total_margine': ['766', '787', '1220', '1007'], 'salse_margin': ['218', '259', '588', '405'], 'pure_margin': ['135', '197', '243', '267']}
# {'company_name': '3M (MMM)', 'symbol': 'MMM', 'total_income': ['7176', '8075', '8111', '7991'], 'total_margine': ['3426', '3975', '3802', '3809'], 'salse_margin': ['1740', '1663', '1325', '2011'], 'pure_margin': ['1290', '1292', '969', '1583']}
# {'company_name': '버텍스 파마슈티컬 (VRTX)', 'symbol': 'VRTX', 'total_income': ['1524.48', '1515.11', '1413.27', '949.83'], 'total_margine': ['1339.96', '1352.61', '1228.25', '817.91'], 'salse_margin': ['718.03', '720.22', '551.47', '99.33'], 'pure_margin': ['837.27', '602.75', '583.23', '57.52']}
# {'company_name': '몬스터 베버리지 (MNST)', 'symbol': 'MNST', 'total_income': ['1093.9', '1062.1', '1017.21', '1133.58'], 'total_margine': ['643.57', '620.1', '594.27', '657'], 'salse_margin': ['407.26', '364.99', '317.05', '395.44'], 'pure_margin': ['311.37', '278.83', '254.95', '298.92']}
# {'company_name': '핍스 서드 (FITB)', 'symbol': 'FITB', 'total_income': ['2051', '2053', '2196', '2595'], 'pure_margin': ['581', '195', '46', '734']}
# {'company_name': '신타스 (CTAS)', 'symbol': 'CTAS', 'total_income': ['1746.58', '1619.58', '1810.65', '3654.89'], 'total_margine': ['826.2', '707.82', '824.39', '1701.53'], 'salse_margin': ['349.71', '207.43', '314.65', '640.61'], 'pure_margin': ['300', '144.59', '234.52', '496.93']}
# {'company_name': '오토데스크 (ADSK)', 'symbol': 'ADSK', 'total_income': ['913.1', '885.7', '899.3', '842.7'], 'total_margine': ['832.2', '803.8', '816.1', '763.2'], 'salse_margin': ['146.1', '130.6', '133.8', '110.6'], 'pure_margin': ['98.2', '66.5', '131.8', '66.7']}
# {'company_name': '디시 네트워크 (DISH)', 'symbol': 'DISH', 'total_income': ['3187.09', '3217.39', '3240.86', '3168.36'], 'total_margine': ['1091.41', '1017.37', '1056.77', '940.87'], 'salse_margin': ['637.65', '144.08', '522.95', '468.85'], 'pure_margin': ['452.34', '73.1', '389.4', '353.3']}
# {'company_name': '길리어드 사이언시스 (GILD)', 'symbol': 'GILD', 'total_income': ['5143', '5548', '5879', '5604'], 'total_margine': ['4079', '4579', '4196', '4569'], 'salse_margin': ['-2983', '2402', '1093', '-1473'], 'pure_margin': ['-3339', '1551', '2696', '-1165']}
# {'company_name': '알파벳 A (GOOGL)', 'symbol': 'GOOGL', 'total_income': ['38297', '41159', '46075', '40499'], 'total_margine': ['19744', '22177', '25055', '22931'], 'salse_margin': ['6383', '7977', '9266', '9177'], 'pure_margin': ['6959', '6836', '10671', '7068']}
# {'company_name': '파이서브 (FISV)', 'symbol': 'FISV', 'total_income': ['3465', '3769', '4045', '3128'], 'total_margine': ['1545', '1602', '1984', '1511'], 'salse_margin': ['165', '629', '478', '423'], 'pure_margin': ['2', '392', '247', '198']}
# {'company_name': '어도비 시스템즈 (ADBE)', 'symbol': 'ADBE', 'total_income': ['3225', '3128', '3091', '2991.95'], 'total_margine': ['2798', '2713', '2639', '2539.96'], 'salse_margin': ['1069', '1016', '937', '969.93'], 'pure_margin': ['955', '1100', '955', '851.86']}
# {'company_name': '퀄컴 (QCOM)', 'symbol': 'QCOM', 'total_income': ['4893', '5216', '5077', '4814'], 'total_margine': ['2813', '2919', '2964', '2696'], 'salse_margin': ['827', '654', '958', '676'], 'pure_margin': ['845', '468', '925', '506']}
# {'company_name': '디스커버리 홀딩스 Series A (DISCA)', 'symbol': 'DISCA', 'total_income': ['2541', '2683', '2874', '2678'], 'total_margine': ['1737', '1766', '1897', '1768'], 'salse_margin': ['646', '779', '705', '619'], 'pure_margin': ['271', '377', '476', '262']}
# {'company_name': '어플라이드 머티어리얼즈 (AMAT)', 'symbol': 'AMAT', 'total_income': ['4395', '3957', '4162', '3754'], 'total_margine': ['1955', '1749', '1858', '1634'], 'salse_margin': ['1108', '932', '1042', '864'], 'pure_margin': ['841', '755', '892', '698']}
# {'company_name': '케이든스디자인시스템 (CDNS)', 'symbol': 'CDNS', 'total_income': ['666.61', '638.42', '617.96', '599.55'], 'total_margine': ['584.32', '563.2', '543.49', '526.23'], 'salse_margin': ['169.27', '151.95', '139.35', '108.9'], 'pure_margin': ['161.63', '131.29', '123.99', '659.67']}
# {'company_name': 'Microchip Technology Inc (MCHP)', 'symbol': 'MCHP', 'total_income': ['1309.7', '1326.4', '1287.4', '1337.8'], 'total_margine': ['798.3', '813.9', '785.5', '827.5'], 'salse_margin': ['191.5', '157.3', '131.2', '183.5'], 'pure_margin': ['123.6', '99.9', '311.1', '108.9']}
# {'company_name': '윈 리조트 (WYNN)', 'symbol': 'WYNN', 'total_income': ['85.7', '953.72', '1653.46', '1647.76'], 'total_margine': ['-154.57', '216.06', '646.34', '611.14'], 'salse_margin': ['-523.63', '-248.25', '226.34', '165.64'], 'pure_margin': ['-637.56', '-402.04', '-72.94', '-3.5']}
# {'company_name': '인튜이티브 서지컬 (ISRG)', 'symbol': 'ISRG', 'total_income': ['1077.7', '852.1', '1099.5', '1277.7'], 'total_margine': ['724.3', '502.9', '738.2', '896'], 'salse_margin': ['270.4', '80.6', '283', '397.6'], 'pure_margin': ['313.9', '68', '313.5', '357.7']}
# {'company_name': '나스닥 (NDAQ)', 'symbol': 'NDAQ', 'total_income': ['1414', '1398', '1353', '1065'], 'total_margine': ['715', '699', '701', '646'], 'salse_margin': ['326', '315', '275', '260'], 'pure_margin': ['264', '241', '203', '203']}
# {'company_name': '헨리 샤인 (HSIC)', 'symbol': 'HSIC', 'total_income': ['1684.4', '2428.87', '2668.94', '2508.77'], 'total_margine': ['454.29', '746.04', '810.6', '761.17'], 'salse_margin': ['-7.43', '173.87', '196.33', '187.2'], 'pure_margin': ['-10.8', '130.26', '329.86', '140.56']}
# {'company_name': '페이첵스 (PAYX)', 'symbol': 'PAYX', 'total_income': ['932.2', '915.1', '1142.7', '990.7'], 'total_margine': ['', '', '', ''], 'salse_margin': ['284', '299.6', '470.1', '341.7'], 'pure_margin': ['211.6', '220.7', '354.5', '258.7']}
# {'company_name': '베리사인 (VRSN)', 'symbol': 'VRSN', 'total_income': ['317.88', '314.37', '312.52', '310.54'], 'total_margine': ['272.86', '270.76', '266.95', '264.09'], 'salse_margin': ['206.64', '211.93', '206.26', '199.38'], 'pure_margin': ['170.98', '152.48', '334.12', '148.32']}
# {'company_name': '애플 (AAPL)', 'symbol': 'AAPL', 'total_income': ['59685', '58313', '91819', '64040'], 'total_margine': ['22680', '22370', '35217', '24313'], 'salse_margin': ['13091', '12853', '25569', '15625'], 'pure_margin': ['11253', '11249', '22236', '13686']}
# {'company_name': '패스널 (FAST)', 'symbol': 'FAST', 'total_income': ['1413.3', '1509', '1367', '1276.9'], 'total_margine': ['640.6', '671.6', '636.8', '598.4'], 'salse_margin': ['290.1', '316', '271.3', '238.9'], 'pure_margin': ['221.5', '238.9', '202.6', '178.7']}
# {'company_name': '덴츠플라이 (XRAY)', 'symbol': 'XRAY', 'total_income': ['490.6', '874.3', '1111.5', '962.1'], 'total_margine': ['176.1', '467.8', '610.6', '514'], 'salse_margin': ['-104.3', '-124.8', '136.6', '109.5'], 'pure_margin': ['-95.4', '-139.9', '102.3', '85']}
# {'company_name': '자이언스 뱅코프 (ZION)', 'symbol': 'ZION', 'total_income': ['712', '756', '799', '823'], 'pure_margin': ['66', '14', '183', '222']}
# {'company_name': '노던 트러스트 (NTRS)', 'symbol': 'NTRS', 'total_income': ['1506.9', '1653.3', '1639', '1666'], 'total_margine': ['1506.1', '1587.7', '1547.7', '1537.9'], 'salse_margin': ['403.2', '461.1', '476.4', '508.6'], 'pure_margin': ['313.3', '360.6', '371.1', '384.6']}
# {'company_name': '시트릭스 시스템즈 (CTXS)', 'symbol': 'CTXS', 'total_income': ['767.17', '798.93', '860.95', '809.82'], 'total_margine': ['639.88', '676.69', '745.37', '690.65'], 'salse_margin': ['128.31', '143.67', '201.55', '185.36'], 'pure_margin': ['98.23', '112.91', '181.22', '207.11']}
# {'company_name': 'C.H.로빈슨 (CHRW)', 'symbol': 'CHRW', 'total_income': ['3627.85', '3805.01', '3793.33', '3856.13'], 'total_margine': ['614.45', '567.95', '578.86', '633.43'], 'salse_margin': ['188.79', '109.44', '136.81', '201.09'], 'pure_margin': ['143.94', '78.15', '99.11', '146.89']}
# {'company_name': '파카 (PCAR)', 'symbol': 'PCAR', 'total_income': ['4936', '3062.2', '5161.7', '6117.2'], 'total_margine': ['977.7', '620.7', '973.3', '1227.2'], 'salse_margin': ['778.2', '202.4', '491.4', '714.9'], 'pure_margin': ['385.5', '147.7', '359.4', '531.3']}
# {'company_name': '아마존닷컴 (AMZN)', 'symbol': 'AMZN', 'total_income': ['88912', '75452', '87436', '69981'], 'total_margine': ['36252', '31195', '33459', '28679'], 'salse_margin': ['5843', '3989', '3879', '3157'], 'pure_margin': ['5243', '2535', '3268', '2134']}
# {'company_name': '로스 스토어스 (ROST)', 'symbol': 'ROST', 'total_income': ['2684.71', '1842.67', '4413.44', '3849.12'], 'total_margine': ['604.59', '-47.32', '1189.21', '1082.68'], 'salse_margin': ['85.1', '-462.62', '587.33', '478.08'], 'pure_margin': ['22.05', '-305.84', '456.13', '370.93']}
# {'company_name': '넷앱 (NTAP)', 'symbol': 'NTAP', 'total_income': ['1303', '1401', '1404', '1371'], 'total_margine': ['872', '941', '941', '925'], 'salse_margin': ['136', '267', '268', '296'], 'pure_margin': ['77', '196', '277', '243']}
# {'company_name': 'Garmin Ltd (GRMN)', 'symbol': 'GRMN', 'total_income': ['869.87', '856.11', '1102.23', '934.38'], 'total_margine': ['515.43', '506.94', '639.46', '567.46'], 'salse_margin': ['188.39', '177.48', '276.52', '261.46'], 'pure_margin': ['184.18', '161.18', '360.79', '227.87']}
# {'company_name': 'Costco Wholesale Corp (COST)', 'symbol': 'COST', 'total_income': ['53383', '37266', '39072', '37040'], 'total_margine': ['7046', '5061', '5016', '4807'], 'salse_margin': ['1929', '1179', '1266', '1061'], 'pure_margin': ['1389', '838', '931', '844']}
# {'company_name': '램리서치 (LRCX)', 'symbol': 'LRCX', 'total_income': ['2791.86', '2503.62', '2583.5', '2165.75'], 'total_margine': ['1280.33', '1167.01', '1179.64', '981.71'], 'salse_margin': ['755.72', '694.11', '686.51', '537.46'], 'pure_margin': ['696.67', '574.78', '514.51', '465.79']}
# {'company_name': '인튜이트 (INTU)', 'symbol': 'INTU', 'total_income': ['1816', '3002', '1696', '1165'], 'total_margine': ['1494', '2576', '1356', '875'], 'salse_margin': ['483', '1413', '270', '10'], 'pure_margin': ['445', '1084', '240', '57']}
# {'company_name': '익스피디아 (EXPE)', 'symbol': 'EXPE', 'total_income': ['566', '2209', '2747', '3558'], 'total_margine': ['177', '1580', '2188', '2989'], 'salse_margin': ['-849', '-1294', '160', '609'], 'pure_margin': ['-736', '-1301', '76', '409']}
# {'company_name': '코그니전트 테크놀로지 솔루션 A (CTSH)', 'symbol': 'CTSH', 'total_income': ['4000', '4225', '4284', '4248'], 'total_margine': ['1410', '1484', '1535', '1567'], 'salse_margin': ['467', '579', '626', '669'], 'pure_margin': ['361', '367', '395', '497']}
# {'company_name': '아카마이 테크놀로지 (AKAM)', 'symbol': 'AKAM', 'total_income': ['794.72', '764.3', '772.12', '709.91'], 'total_margine': ['517.91', '495.72', '514.37', '462.97'], 'salse_margin': ['190.43', '152.33', '135.32', '143.29'], 'pure_margin': ['161.91', '123.15', '119.1', '137.89']}
# {'company_name': 'KLA (KLAC)', 'symbol': 'KLAC', 'total_income': ['1459.59', '1423.96', '1509.45', '1413.41'], 'total_margine': ['838.05', '833.79', '875.85', '810.97'], 'salse_margin': ['453.16', '153.43', '462.83', '410.25'], 'pure_margin': ['411.25', '78.45', '380.56', '346.52']}
# {'company_name': '주니퍼 네트웍스 (JNPR)', 'symbol': 'JNPR', 'total_income': ['1086.3', '998', '1208.1', '1133.1'], 'total_margine': ['619.6', '579.3', '719.3', '678.4'], 'salse_margin': ['90.5', '39.4', '178.6', '123.2'], 'pure_margin': ['61.2', '20.4', '168.4', '99.3']}
# {'company_name': '액티비전 블리자드 (ATVI)', 'symbol': 'ATVI', 'total_income': ['1932', '1788', '1986', '1282'], 'total_margine': ['1463', '1283', '1329', '840'], 'salse_margin': ['749', '612', '454', '247'], 'pure_margin': ['580', '505', '525', '204']}
# {'company_name': '암젠 (AMGN)', 'symbol': 'AMGN', 'total_income': ['6206', '6161', '6197', '5737'], 'total_margine': ['4718', '4648', '4944', '4701'], 'salse_margin': ['2323', '2355', '2048', '2476'], 'pure_margin': ['1803', '1825', '1703', '1968']}
# {'company_name': '자일링스 (XLNX)', 'symbol': 'XLNX', 'total_income': ['766.53', '726.67', '756.17', '723.5'], 'total_margine': ['541.72', '493.87', '528.43', '483.48'], 'salse_margin': ['205.42', '175.51', '178.03', '159.41'], 'pure_margin': ['193.82', '93.84', '162.26', '162.01']}
# {'company_name': 'Expeditors International of Washington Inc (EXPD)', 'symbol': 'EXPD', 'total_income': ['2580.63', '1901.86', '2044.94', '2074.86'], 'total_margine': ['749.59', '615.14', '646.3', '674.36'], 'salse_margin': ['247.63', '159.06', '180.34', '206.55'], 'pure_margin': ['183.87', '122.34', '137.33', '160.22']}
# {'company_name': '일렉트로닉 아츠 (EA)', 'symbol': 'EA', 'total_income': ['1459', '1387', '1593', '1348'], 'total_margine': ['1171', '1118', '1085', '943'], 'salse_margin': ['471', '401', '361', '268'], 'pure_margin': ['365', '418', '346', '854']}
# {'company_name': 'T. Rowe Price Group Inc (TROW)', 'symbol': 'TROW', 'total_income': ['1415.4', '1462.6', '1468.7', '1426.7'], 'total_margine': ['', '', '', ''], 'salse_margin': ['553.7', '707.3', '580.3', '659'], 'pure_margin': ['603', '343.1', '545.3', '545.9']}
# {'company_name': '바이오젠 (BIIB)', 'symbol': 'BIIB', 'total_income': ['3376.1', '3681.6', '3534.3', '3671.3'], 'total_margine': ['2927', '3270.5', '3080', '3224.2'], 'salse_margin': ['1086.4', '1974.5', '1819.9', '1777.7'], 'pure_margin': ['701.5', '1542.1', '1399.1', '1439.7']}
# {'company_name': '찰스 슈왑 (SCHW)', 'symbol': 'SCHW', 'total_income': ['2537', '2547', '2753', '2774'], 'total_margine': ['2448', '2450', '2617', '2606'], 'salse_margin': ['889', '888', '1047', '1112'], 'pure_margin': ['698', '671', '795', '852']}
# {'company_name': '헌팅턴 뱅크셰어스 (HBAN)', 'symbol': 'HBAN', 'total_income': ['1322', '1293', '1336', '1383'], 'pure_margin': ['303', '150', '48', '317']}
# {'company_name': '노턴라이프록 (NLOK)', 'symbol': 'NLOK', 'total_income': ['614', '614', '618', '1258'], 'total_margine': ['528', '517', '515', '1065'], 'salse_margin': ['140', '275', '62', '249'], 'pure_margin': ['118', '231', '2845', '811']}
# {'company_name': '엔비디아 코퍼레이션 (NVDA)', 'symbol': 'NVDA', 'total_income': ['3866', '3080', '3105', '3014'], 'total_margine': ['2275', '2004', '2015', '1916'], 'salse_margin': ['651', '976', '990', '927'], 'pure_margin': ['622', '917', '951', '899']}
# {'company_name': '스타벅스 (SBUX)', 'symbol': 'SBUX', 'total_income': ['4222.1', '5995.7', '7097.1', '6747'], 'total_margine': ['200.3', '1276.6', '2039.2', '1858.8'], 'salse_margin': ['-703.9', '487.4', '1219.8', '1083.3'], 'pure_margin': ['-678.4', '328.4', '885.7', '802.8']}
# {'company_name': '신시내티 파이낸셜 (CINF)', 'symbol': 'CINF', 'total_income': ['2714', '-99', '2152', '1700'], 'salse_margin': ['1159', '-1563', '794', '308'], 'pure_margin': ['909', '-1226', '626', '248']}
# {'company_name': '홀로직 (HOLX)', 'symbol': 'HOLX', 'total_income': ['822.9', '756.1', '850.5', '865.9'], 'total_margine': ['466.1', '395.8', '459.6', '453.6'], 'salse_margin': ['191', '156.4', '124.8', '-86.5'], 'pure_margin': ['137.9', '96.3', '386.1', '-123.5']}
# {'company_name': '컴캐스트 (CMCSA)', 'symbol': 'CMCSA', 'total_income': ['23715', '26609', '28398', '26827'], 'total_margine': ['16898', '18308', '19098', '18511'], 'salse_margin': ['4647', '4852', '5247', '5340'], 'pure_margin': ['2988', '2147', '3162', '3217']}
# {'company_name': '메드트로닉 (MDT)', 'symbol': 'MDT', 'total_income': ['6507', '5997', '7717', '7706'], 'total_margine': ['4029', '3765', '5367', '5344'], 'salse_margin': ['673', '316', '1639', '1351'], 'pure_margin': ['487', '646', '1915', '1364']}
# {'company_name': '도버 (DOV)', 'symbol': 'DOV', 'total_income': ['1748.26', '1499.17', '1655.94', '1775.59'], 'total_margine': ['661.44', '559.15', '613.78', '655.79'], 'salse_margin': ['276.34', '184.08', '231.85', '224.55'], 'pure_margin': ['200.3', '124.77', '176.28', '168.12']}
# {'company_name': '노스롭 그루먼 (NOC)', 'symbol': 'NOC', 'total_income': ['9083', '8884', '8620', '8721'], 'total_margine': ['1840', '1826', '1722', '2106'], 'salse_margin': ['985', '994', '934', '1136'], 'pure_margin': ['986', '1005', '868', '-409']}
# {'company_name': 'MGM 리조트 인터내셔널 (MGM)', 'symbol': 'MGM', 'total_income': ['289.81', '2252.82', '3185.14', '3314.38'], 'total_margine': ['-84.56', '814.65', '1285.49', '1377.73'], 'salse_margin': ['-1034.53', '1250.85', '2960.09', '238.38'], 'pure_margin': ['-857.26', '806.87', '2011.58', '-37.13']}
# {'company_name': '보나도 (VNO)', 'symbol': 'VNO', 'total_income': ['343.03', '444.53', '460.97', '465.96'], 'total_margine': ['168.6', '214.53', '236.99', '239.6'], 'salse_margin': ['103.65', '80.07', '97.17', '107.38'], 'pure_margin': ['-185.22', '17.49', '205.75', '335.44']}
# {'company_name': '마스터카드 (MA)', 'symbol': 'MA', 'total_income': ['3335', '4009', '4414', '4467'], 'total_margine': ['', '', '', ''], 'salse_margin': ['1707', '2211', '2399', '2655'], 'pure_margin': ['1420', '1693', '2100', '2108']}
# {'company_name': '제너럴 다이내믹스 (GD)', 'symbol': 'GD', 'total_income': ['9264', '8749', '10773', '9761'], 'total_margine': ['1415', '1488', '1957', '1788'], 'salse_margin': ['841', '941', '1328', '1216'], 'pure_margin': ['625', '706', '1020', '913']}
# {'company_name': 'DTE 에너지 (DTE)', 'symbol': 'DTE', 'total_income': ['2583', '3022', '3148', '3119'], 'salse_margin': ['367', '546', '415', '450'], 'pure_margin': ['277', '340', '267', '319']}
# {'company_name': '아나로그디바이스 (ADI)', 'symbol': 'ADI', 'total_income': ['1456.14', '1317.06', '1303.57', '1443.22'], 'total_margine': ['972.58', '846.67', '848.14', '942.19'], 'salse_margin': ['419.12', '344.02', '273.43', '338.36'], 'pure_margin': ['362.67', '267.7', '203.87', '277.69']}
# {'company_name': 'VF 코퍼레이션 (VFC)', 'symbol': 'VFC', 'total_income': ['2608.32', '1076.29', '1439.06', '3384.75'], 'total_margine': ['1325.92', '583.34', '899.23', '1884.48'], 'salse_margin': ['319.95', '-246.81', '-425.11', '553.86'], 'pure_margin': ['256.72', '-285.61', '-483.78', '465']}
# {'company_name': '카디널 헬스 (CAH)', 'symbol': 'CAH', 'total_income': ['36689', '39157', '39735', '37341'], 'total_margine': ['1590', '1885', '1714', '1679'], 'salse_margin': ['263', '557', '330', '-5264'], 'pure_margin': ['656', '350', '220', '-4922']}
# {'company_name': '엑셀 에너지 (XEL)', 'symbol': 'XEL', 'total_income': ['2586', '2811', '2798', '3013'], 'salse_margin': ['422', '455', '450', '758'], 'pure_margin': ['287', '295', '292', '527']}
# {'company_name': 'DR호튼 (DHI)', 'symbol': 'DHI', 'total_income': ['5390', '4500', '4020.7', '5038.9'], 'total_margine': ['1310.2', '1058', '940', '1169.6'], 'salse_margin': ['782.4', '621.3', '523.3', '660.1'], 'pure_margin': ['630.7', '482.7', '431.3', '505.3']}
# {'company_name': '인터퍼블릭그룹 (IPG)', 'symbol': 'IPG', 'total_income': ['2125.5', '2025.7', '2359.8', '2901.8'], 'total_margine': ['376.8', '230.3', '171.1', '581.2'], 'salse_margin': ['240', '20.6', '52.6', '467.4'], 'pure_margin': ['279.7', '-45.6', '4.7', '328.9']}
# {'company_name': '록히드 마틴 (LMT)', 'symbol': 'LMT', 'total_income': ['16495', '16220', '15651', '15878'], 'total_margine': ['2136', '2213', '2091', '2123'], 'salse_margin': ['2147', '2086', '2122', '2149'], 'pure_margin': ['1698', '1626', '1717', '1498']}
# {'company_name': '워터스 코퍼레이션 (WAT)', 'symbol': 'WAT', 'total_income': ['519.98', '464.94', '716.29', '577.28'], 'total_margine': ['306.85', '254.29', '417.23', '336.22'], 'salse_margin': ['155.11', '68.28', '236.42', '173.24'], 'pure_margin': ['122.93', '53.56', '200.67', '138.13']}
# {'company_name': '액센츄어 (ACN)', 'symbol': 'ACN', 'total_income': ['10835.27', '10991.31', '11141.5', '11358.96'], 'total_margine': ['3440.54', '3528.69', '3359.17', '3647.76'], 'salse_margin': ['1544.7', '1712.73', '1488.94', '1767.26'], 'pure_margin': ['1287.93', '1228.2', '1234.74', '1356.97']}
# {'company_name': '도미니언 에너지 (D)', 'symbol': 'D', 'total_income': ['3585', '4496', '4475', '4269'], 'salse_margin': ['540', '631', '1239', '1314'], 'pure_margin': ['-1169', '-270', '1009', '975']}
# {'company_name': '엑슨모빌 (XOM)', 'symbol': 'XOM', 'total_income': ['32277', '55134', '63024', '63422'], 'total_margine': ['11313', '14754', '18770', '19284'], 'salse_margin': ['-1651', '-1033', '2466', '3326'], 'pure_margin': ['-1080', '-610', '5690', '3170']}
# {'company_name': 'Cigna Corp (CI)', 'symbol': 'CI', 'total_income': ['39303', '38315', '38338', '38607'], 'salse_margin': ['2663', '1788', '1652', '2174'], 'pure_margin': ['1754', '1181', '977', '1351']}
# {'company_name': 'Public Service Enterprise Group Inc (PEG)', 'symbol': 'PEG', 'total_income': ['2050', '2781', '2478', '2302'], 'salse_margin': ['407', '797', '507', '490'], 'pure_margin': ['451', '448', '437', '403']}
# {'company_name': '니소스 (NI)', 'symbol': 'NI', 'total_income': ['962.7', '1605.5', '1397.2', '931.5'], 'salse_margin': ['91.7', '148.2', '-38', '91'], 'pure_margin': ['-4.7', '75.6', '-139.3', '6.6']}
# {'company_name': '짐머 바이오메트 (ZBH)', 'symbol': 'ZBH', 'total_income': ['1226.1', '1783.8', '2125.7', '1892.4'], 'total_margine': ['801.6', '1312.3', '1479.3', '1368'], 'salse_margin': ['-171.7', '-456', '336.8', '245.8'], 'pure_margin': ['-206.6', '-508.5', '320.7', '431.1']}
# {'company_name': 'CSX (CSX)', 'symbol': 'CSX', 'total_income': ['2648', '2255', '2855', '2885'], 'total_margine': ['2151', '1757', '2209', '2233'], 'salse_margin': ['1141', '828', '1178', '1154'], 'pure_margin': ['736', '499', '770', '771']}
# {'company_name': 'Intercontinental Exchange Inc (ICE)', 'symbol': 'ICE', 'total_income': ['1395', '1559', '1298', '1336'], 'total_margine': ['', '', '', ''], 'salse_margin': ['744', '882', '622', '706'], 'pure_margin': ['523', '650', '448', '529']}
# {'company_name': '사우스웨스트 에어라인 (LUV)', 'symbol': 'LUV', 'total_income': ['1008', '4234', '5730', '5639'], 'total_margine': ['476', '3025', '4298', '4204'], 'salse_margin': ['-1127', '-110', '665', '819'], 'pure_margin': ['-915', '-94', '513', '659']}
# {'company_name': '일리노이 툴 웍스 (ITW)', 'symbol': 'ITW', 'total_income': ['3307', '2564', '3228', '3469'], 'total_margine': ['1397', '970', '1357', '1447'], 'salse_margin': ['789', '449', '761', '824'], 'pure_margin': ['582', '319', '566', '641']}
# {'company_name': '다든 레스토랑 (DRI)', 'symbol': 'DRI', 'total_income': ['1527.4', '1270.1', '2346.5', '2056.4'], 'total_margine': ['301.3', '10.5', '538', '405.5'], 'salse_margin': ['56.6', '-590.5', '278.3', '13.1'], 'pure_margin': ['36.1', '-480', '232.3', '24.7']}
# {'company_name': '트루이스트 파이낸셜 (TFC)', 'symbol': 'TFC', 'total_income': ['', '', '', ''], 'total_margine': ['', '', '', ''], 'salse_margin': ['', '', '', ''], 'pure_margin': ['825', '886', '792', '798']}
# {'company_name': '할리버튼 (HAL)', 'symbol': 'HAL', 'total_income': ['3196', '5037', '5191', '5550'], 'total_margine': ['279', '556', '605', '589'], 'salse_margin': ['-1911', '-739', '-1652', '536'], 'pure_margin': ['-1676', '-1017', '-1653', '295']}
# {'company_name': '프로로지스 (PLD)', 'symbol': 'PLD', 'total_income': ['1082.77', '1266.12', '978.24', '826.02'], 'total_margine': ['791.49', '952.47', '704.05', '595.83'], 'salse_margin': ['215.12', '458.06', '231.05', '237.5'], 'pure_margin': ['302.69', '406.17', '491.05', '386.99']}
# {'company_name': '맥코믹 (MKC)', 'symbol': 'MKC', 'total_income': ['1430.3', '1401.1', '1212', '1484.8'], 'total_margine': ['590.3', '579.5', '469.9', '630'], 'salse_margin': ['273', '257.4', '194.2', '299.2'], 'pure_margin': ['206.1', '195.9', '144.7', '213.4']}
# {'company_name': '갭 (GPS)', 'symbol': 'GPS', 'total_income': ['3275', '2107', '4674', '3998'], 'total_margine': ['1149', '268', '1674', '1559'], 'salse_margin': ['15', '-1244', '-245', '221'], 'pure_margin': ['-62', '-932', '-184', '140']}
# {'company_name': '호스트 호텔 & 리조트 (HST)', 'symbol': 'HST', 'total_income': ['103', '1052', '1334', '1262'], 'total_margine': ['', '', '', ''], 'salse_margin': ['-353', '-11', '113', '134'], 'pure_margin': ['-352', '-3', '80', '368']}
# {'company_name': '에스티 로더 (EL)', 'symbol': 'EL', 'total_income': ['2430', '3345', '4624', '3895'], 'total_margine': ['1663', '2509', '3583', '2987'], 'salse_margin': ['-543', '109', '261', '779'], 'pure_margin': ['-462', '-6', '557', '595']}
# {'company_name': '인터내셔널 페이퍼 (IP)', 'symbol': 'IP', 'total_income': ['4866', '5352', '5498', '5568'], 'total_margine': ['1439', '1620', '1829', '1802'], 'salse_margin': ['363', '76', '519', '590'], 'pure_margin': ['266', '-141', '165', '344']}
# {'company_name': '에머슨 일렉트릭 (EMR)', 'symbol': 'EMR', 'total_income': ['3914', '4163', '4153', '4971'], 'total_margine': ['1618', '1754', '1765', '2128'], 'salse_margin': ['503', '729', '464', '866'], 'pure_margin': ['399', '517', '326', '717']}
# {'company_name': 'Clorox Co (CLX)', 'symbol': 'CLX', 'total_income': ['1983', '1783', '1449', '1506'], 'total_margine': ['929', '832', '639', '663'], 'salse_margin': ['395', '297', '235', '258'], 'pure_margin': ['310', '241', '185', '203']}
# {'company_name': '코노코필립스 (COP)', 'symbol': 'COP', 'total_income': ['2749', '6111', '7635', '7752'], 'total_margine': ['572', '2304', '3608', '3720'], 'salse_margin': ['-398', '-16', '1039', '3179'], 'pure_margin': ['260', '-1739', '720', '3056']}
# {'company_name': '콜게이트-팜올리브 (CL)', 'symbol': 'CL', 'total_income': ['3897', '4097', '4015', '3928'], 'total_margine': ['2369', '2465', '2413', '2317'], 'salse_margin': ['946', '952', '928', '855'], 'pure_margin': ['635', '715', '643', '578']}
# {'company_name': 'Pinnacle West Capital Corp (PNW)', 'symbol': 'PNW', 'total_income': ['929.59', '661.93', '670.39', '1190.79'], 'salse_margin': ['261.87', '40.42', '12', '403.29'], 'pure_margin': ['193.59', '29.99', '63.98', '312.28']}
# {'company_name': '리전스 파이낸셜 (RF)', 'symbol': 'RF', 'total_income': ['1714', '1636', '1564', '1670'], 'pure_margin': ['530', '-214', '162', '389']}
# {'company_name': '센터포인트 에너지 (CNP)', 'symbol': 'CNP', 'total_income': ['1575', '2167', '3230', '2742'], 'salse_margin': ['235', '217', '302', '392'], 'pure_margin': ['105', '-1199', '157', '270']}
# {'company_name': '메트라이프 (MET)', 'symbol': 'MET', 'total_income': ['14099', '18310', '17273', '18678'], 'salse_margin': ['429', '5865', '187', '3014'], 'pure_margin': ['145', '4398', '593', '2184']}
# {'company_name': '엑셀론 (EXC)', 'symbol': 'EXC', 'total_income': ['7322', '8747', '8342', '8929'], 'salse_margin': ['565', '1220', '962', '1353'], 'pure_margin': ['521', '582', '772', '772']}
# {'company_name': '박스터 인터내셔널 (BAX)', 'symbol': 'BAX', 'total_income': ['2718', '2802', '3039', '2851'], 'total_margine': ['1045', '1171', '1325', '1239'], 'salse_margin': ['331', '409', '-219', '503'], 'pure_margin': ['246', '332', '-23', '369']}
# {'company_name': '옥시덴탈 (OXY)', 'symbol': 'OXY', 'total_income': ['2961', '6647', '6324', '5743'], 'total_margine': ['1172', '4008', '3995', '3515'], 'salse_margin': ['-8006', '-975', '-1393', '-439'], 'pure_margin': ['-8131', '-2013', '-1139', '-794']}
# {'company_name': '서던 컴퍼니 (SO)', 'symbol': 'SO', 'total_income': ['4620', '5018', '4914', '5995'], 'salse_margin': ['904', '1263', '690', '2013'], 'pure_margin': ['616', '872', '445', '1320']}
# {'company_name': '태피스트리 (TPR)', 'symbol': 'TPR', 'total_income': ['714.8', '1072.7', '1816', '1357.9'], 'total_margine': ['514.6', '720.2', '1211.2', '918.6'], 'salse_margin': ['-280', '-685.5', '363.1', '51.6'], 'pure_margin': ['-293.8', '-677.1', '298.8', '20']}
# {'company_name': '레나  (LEN)', 'symbol': 'LEN', 'total_income': ['5870.25', '5287.37', '4505.34', '6971.53'], 'total_margine': ['1062.41', '832.18', '609.57', '1100.97'], 'salse_margin': ['859.01', '676.58', '423.55', '888.69'], 'pure_margin': ['666.42', '517.41', '398.45', '674.3']}
# {'company_name': '켐벨 수프 (CPB)', 'symbol': 'CPB', 'total_income': ['2108', '2238', '2162', '2183'], 'total_margine': ['735', '806', '744', '734'], 'salse_margin': ['149', '353', '347', '318'], 'pure_margin': ['86', '168', '1208', '166']}
# {'company_name': '센츄리링크 (LUMN)', 'symbol': 'LUMN', 'total_income': ['5192', '5228', '5570', '5606'], 'total_margine': ['2960', '2993', '3049', '3016'], 'salse_margin': ['903', '980', '847', '950'], 'pure_margin': ['377', '314', '223', '302']}
# {'company_name': 'State Street Corp (STT)', 'symbol': 'STT', 'total_income': ['2826', '3052', '3269', '3318'], 'pure_margin': ['555', '694', '634', '564']}
# {'company_name': 'Progressive Corp (PGR)', 'symbol': 'PGR', 'total_income': ['10967.2', '9318.1', '10734.8', '9524.6'], 'salse_margin': ['2325.2', '922.7', '1386.3', '1057.8'], 'pure_margin': ['1790.4', '699.1', '1070.8', '841.7']}
# {'company_name': '벌칸 머티리얼 (VMC)', 'symbol': 'VMC', 'total_income': ['1322.58', '1049.24', '1186.15', '1418.76'], 'total_margine': ['396.52', '201.72', '293.08', '400.64'], 'salse_margin': ['298.9', '112.3', '193.58', '303.38'], 'pure_margin': ['209.92', '60.26', '141.09', '215.71']}
# {'company_name': '파카 하니핀 (PH)', 'symbol': 'PH', 'total_income': ['3160.6', '3702.43', '3497.97', '3334.51'], 'total_margine': ['840.85', '945.94', '822.89', '858.12'], 'salse_margin': ['370.57', '454.16', '254.75', '433.16'], 'pure_margin': ['295.72', '367.25', '204.47', '338.9']}
# {'company_name': 'Genuine Parts Co (GPC)', 'symbol': 'GPC', 'total_income': ['4370.09', '3823.23', '4092.53', '4706.19'], 'total_margine': ['1528.07', '1290.49', '1388.18', '1585.09'], 'salse_margin': ['302.21', '-290.92', '168.73', '21.53'], 'pure_margin': ['227.53', '-564.37', '136.53', '8.92']}
# {'company_name': 'CBRE Group Inc Class A (CBRE)', 'symbol': 'CBRE', 'total_income': ['5381.38', '5889.17', '7119.41', '5925.1'], 'total_margine': ['989.25', '1176.49', '1598.65', '1249.16'], 'salse_margin': ['94.17', '220.29', '513.84', '316.63'], 'pure_margin': ['81.9', '172.19', '637.62', '256.6']}
# {'company_name': '듀폰 (DD)', 'symbol': 'DD', 'total_income': ['4828', '5221', '5204', '5426'], 'total_margine': ['1537', '1903', '1796', '1895'], 'salse_margin': ['-2400', '-624', '372', '521'], 'pure_margin': ['-2478', '-616', '176', '372']}
# {'company_name': 'Sherwin-Williams Co (SHW)', 'symbol': 'SHW', 'total_income': ['4604', '4146.7', '4114.43', '4867.65'], 'total_margine': ['2208.9', '1889.7', '1894.03', '2225.55'], 'salse_margin': ['753.8', '393.4', '259.19', '726.07'], 'pure_margin': ['595.9', '321.7', '248.62', '576.44']}
# {'company_name': '화이자 (PFE)', 'symbol': 'PFE', 'total_income': ['11801', '12028', '12688', '12680'], 'total_margine': ['9569', '9682', '10092', '10225'], 'salse_margin': ['3441', '4588', '-3844', '11113'], 'pure_margin': ['3426', '3401', '-336', '7680']}
# {'company_name': '웰스 파고 (WFC)', 'symbol': 'WFC', 'total_income': ['20294', '19757', '21132', '24255'], 'pure_margin': ['2035', '-2379', '653', '2873']}
# {'company_name': '월마트 (WMT)', 'symbol': 'WMT', 'total_income': ['137742', '134622', '141671', '127991'], 'total_margine': ['35053', '32596', '33923', '32091'], 'salse_margin': ['6059', '5224', '5322', '4718'], 'pure_margin': ['6476', '3990', '4141', '3288']}
# {'company_name': '에디슨 인터내셔널 (EIX)', 'symbol': 'EIX', 'total_income': ['2987', '2790', '2970', '3741'], 'salse_margin': ['500', '302', '287', '636'], 'pure_margin': ['348', '213', '173', '502']}
# {'company_name': 'Snap-On Inc (SNA)', 'symbol': 'SNA', 'total_income': ['1027.4', '808.9', '938.1', '1039.1'], 'total_margine': ['556', '430.9', '512.6', '534.4'], 'salse_margin': ['251.3', '148.7', '195.8', '233.6'], 'pure_margin': ['179.7', '101.2', '137.2', '170.6']}
# {'company_name': 'Xerox Corp (XRX)', 'symbol': 'XRX', 'total_income': ['1465', '1860', '2444', '6622'], 'total_margine': ['564', '712', '1016', '2634'], 'salse_margin': ['50', '14', '351', '557'], 'pure_margin': ['27', '-2', '818', '535']}
# {'company_name': '에퀴팩스 (EFX)', 'symbol': 'EFX', 'total_income': ['1068.3', '982.8', '957.9', '905.8'], 'total_margine': ['635.1', '573.5', '543.8', '523'], 'salse_margin': ['204.4', '166.8', '135.9', '47.1'], 'pure_margin': ['224.2', '95.9', '112.6', '9.2']}
# {'company_name': '맥케슨 (MCK)', 'symbol': 'MCK', 'total_income': ['55679', '58535', '59172', '57616'], 'total_margine': ['2700', '3336', '3033', '2867'], 'salse_margin': ['678', '1593', '343', '360'], 'pure_margin': ['444', '1021', '186', '-730']}
# {'company_name': '엔터지 (ETR)', 'symbol': 'ETR', 'total_income': ['2412.79', '2427.18', '2462.31', '3140.57'], 'salse_margin': ['439.31', '399.76', '248.54', '519.93'], 'pure_margin': ['365.11', '123.29', '389.61', '369.46']}
# {'company_name': 'CMS Energy Corp (CMS)', 'symbol': 'CMS', 'total_income': ['1443', '1864', '1795', '1546'], 'salse_margin': ['273', '368', '311', '351'], 'pure_margin': ['136', '243', '167', '207']}
# {'company_name': '아메리프라이즈 파이낸셜 (AMP)', 'symbol': 'AMP', 'total_income': ['2730', '3026', '3104', '3351'], 'total_margine': ['1510', '1915', '1203', '1625'], 'salse_margin': ['-485', '2397', '584', '693'], 'pure_margin': ['-539', '2036', '463', '543']}
# {'company_name': 'American International Group Inc (AIG)', 'symbol': 'AIG', 'total_income': ['9396', '14443', '11852', '12938'], 'salse_margin': ['-9296', '2913', '1396', '1608'], 'pure_margin': ['-7928', '1749', '929', '656']}
# {'company_name': '랄프로렌 A (RL)', 'symbol': 'RL', 'total_income': ['487.5', '1274.1', '1750.7', '1706.2'], 'total_margine': ['350', '595.6', '1089.1', '1049.4'], 'salse_margin': ['-168', '-283.8', '224.4', '233.1'], 'pure_margin': ['-127.7', '-249', '334.1', '182.1']}
# {'company_name': '레거트 앤 플래트 (LEG)', 'symbol': 'LEG', 'total_income': ['845.1', '1045.5', '1144.9', '1239.3'], 'total_margine': ['146.3', '222.8', '272.4', '275.5'], 'salse_margin': ['22.8', '80.7', '135.1', '144.1'], 'pure_margin': ['-6.1', '45.7', '86.8', '99.6']}
# {'company_name': 'L 브랜즈 (LB)', 'symbol': 'LB', 'total_income': ['2319', '1654', '4707', '2677'], 'total_margine': ['828', '385', '1838', '959'], 'salse_margin': ['44', '-318', '81', '-188'], 'pure_margin': ['-49', '-297', '-192', '-252']}
# {'company_name': 'International Flavors & Fragrances Inc (IFF)', 'symbol': 'IFF', 'total_income': ['1198.77', '1347.32', '1283.77', '1267.35'], 'total_margine': ['481.84', '565.87', '502.16', '533.09'], 'salse_margin': ['119.37', '196.22', '116.8', '184.66'], 'pure_margin': ['86.2', '124.61', '83.54', '127.12']}
# {'company_name': 'WW 그레인저 (GWW)', 'symbol': 'GWW', 'total_income': ['2837', '3001', '2847', '2947'], 'total_margine': ['1016', '1121', '1082', '1099'], 'salse_margin': ['205', '159', '181', '338'], 'pure_margin': ['114', '173', '103', '233']}
# {'company_name': '컨스텔레이션 브랜드 (STZ)', 'symbol': 'STZ', 'total_income': ['2260.4', '1963.4', '1902.9', '1999.4'], 'total_margine': ['1215.8', '988.3', '949.8', '987.5'], 'salse_margin': ['838.1', '603', '545.1', '267.2'], 'pure_margin': ['512.1', '-177.9', '398.4', '360.4']}
# {'company_name': 'American Tower Corp (AMT)', 'symbol': 'AMT', 'total_income': ['1913', '1993.1', '1923.7', '1953.6'], 'total_margine': ['1373', '1441.1', '1373.5', '1393.7'], 'salse_margin': ['691.3', '702.2', '661.3', '728.3'], 'pure_margin': ['446.1', '415', '562.7', '498.6']}
# {'company_name': '필립 모리스 (PM)', 'symbol': 'PM', 'total_income': ['7446', '6651', '7153', '7713'], 'total_margine': ['5030', '4472', '4751', '4935'], 'salse_margin': ['3243', '2731', '2789', '2506'], 'pure_margin': ['2307', '1947', '1826', '1616']}
# {'company_name': '피델리티 내셔널 인포메이션 서비스(FIS) (FIS)', 'symbol': 'FIS) (FIS', 'total_income': ['2962', '3078', '3342', '2822'], 'total_margine': ['916', '989', '1355', '984'], 'salse_margin': ['46', '108', '123', '140'], 'pure_margin': ['19', '15', '-158', '154']}
# {'company_name': '알트리아 그룹 (MO)', 'symbol': 'MO', 'total_income': ['6367', '6359', '6007', '6856'], 'total_margine': ['3289', '2873', '3087', '3498'], 'salse_margin': ['2835', '2194', '-1796', '-2198'], 'pure_margin': ['1943', '1552', '-1809', '-2600']}
# {'company_name': '볼 코퍼레이션 (BLL)', 'symbol': 'BLL', 'total_income': ['2801', '2785', '2719', '2953'], 'total_margine': ['571', '569', '560', '591'], 'salse_margin': ['178', '155', '206', '198'], 'pure_margin': ['94', '23', '160', '92']}
# {'company_name': '하트포드 (HIG)', 'symbol': 'HIG', 'total_income': ['5068', '4956', '5362', '5348'], 'salse_margin': ['649', '408', '741', '720'], 'pure_margin': ['468', '273', '548', '535']}
# {'company_name': '허쉬 (HSY)', 'symbol': 'HSY', 'total_income': ['1707.33', '2037.32', '2068.12', '2134.42'], 'total_margine': ['792.55', '866.62', '911.91', '943.32'], 'salse_margin': ['375.93', '371.7', '254.31', '452.04'], 'pure_margin': ['268.9', '271.14', '207.19', '325.31']}
# {'company_name': 'DXC 테크놀로지 (DXC)', 'symbol': 'DXC', 'total_income': ['4502', '4815', '5021', '4851'], 'total_margine': ['873', '1042', '1194', '1172'], 'salse_margin': ['-142', '-3518', '188', '-2003'], 'pure_margin': ['-205', '-3495', '82', '-2119']}
# {'company_name': '모건 스탠리 (MS)', 'symbol': 'MS', 'total_income': ['12227', '14172', '11634', '13376'], 'total_margine': ['10960', '12698', '8747', '10224'], 'salse_margin': ['3487', '4355', '2146', '2733'], 'pure_margin': ['2717', '3196', '1698', '2239']}
# {'company_name': 'PNC 파이낸셜 (PNC)', 'symbol': 'PNC', 'total_income': ['4473', '4404', '5025', '5455'], 'pure_margin': ['1519', '3648', '908', '1367']}
# {'company_name': '웨이스트 매니지먼트 (WM)', 'symbol': 'WM', 'total_income': ['3561', '3729', '3846', '3967'], 'total_margine': ['1684', '1735', '1875', '1871'], 'salse_margin': ['527', '566', '655', '733'], 'pure_margin': ['307', '361', '447', '495']}
# {'company_name': '아메리소스버진 (ABC)', 'symbol': 'ABC', 'total_income': ['45366.78', '47417.64', '47864.74', '45637.8'], 'total_margine': ['1222.22', '1336.11', '1143.91', '1181.6'], 'salse_margin': ['382.66', '309.51', '263.44', '179.84'], 'pure_margin': ['289.44', '960.28', '187.64', '132.62']}
# {'company_name': '어슈어런트 (AIZ)', 'symbol': 'AIZ', 'total_income': ['2474.5', '2556.4', '2607.9', '2499.5'], 'salse_margin': ['253.1', '121.6', '236.7', '128.7'], 'pure_margin': ['178.1', '154.7', '127.6', '-54.8']}
# {'company_name': '크로거 (KR)', 'symbol': 'KR', 'total_income': ['30489', '41549', '28893', '27974'], 'total_margine': ['6938', '10095', '6386', '6176'], 'salse_margin': ['820', '1326', '537', '254'], 'pure_margin': ['819', '1212', '327', '263']}
# {'company_name': '몰슨 쿠어스 양조 (TAP)', 'symbol': 'TAP', 'total_income': ['2503.4', '2102.8', '2486.2', '2841.6'], 'total_margine': ['1046.8', '623.8', '966.2', '1156.2'], 'salse_margin': ['458', '-92.5', '310.9', '-237.3'], 'pure_margin': ['195', '-117', '163.7', '-402.8']}
# {'company_name': '홈디포 (HD)', 'symbol': 'HD', 'total_income': ['38053', '28260', '25782', '27223'], 'total_margine': ['12941', '9625', '8736', '9387'], 'salse_margin': ['6067', '3276', '3403', '3947'], 'pure_margin': ['4332', '2245', '2481', '2769']}
# {'company_name': '벡톤 디킨슨 (BDX)', 'symbol': 'BDX', 'total_income': ['3855', '4253', '4225', '4584'], 'total_margine': ['1660', '1773', '1978', '2266'], 'salse_margin': ['358', '370', '501', '111'], 'pure_margin': ['286', '183', '277', '162']}
# {'company_name': 'JM 스머커 (SJM)', 'symbol': 'SJM', 'total_income': ['1971.8', '2092', '1972.3', '1957.8'], 'total_margine': ['775.4', '788.4', '760', '754'], 'salse_margin': ['361.1', '346.7', '289', '329.8'], 'pure_margin': ['237', '226.3', '187.4', '211.2']}
# {'company_name': '실드 에어 (SEE)', 'symbol': 'SEE', 'total_income': ['1151.2', '1173.9', '1298.9', '1218.5'], 'total_margine': ['389.9', '390.5', '429.3', '392'], 'salse_margin': ['186', '186.8', '188.9', '154'], 'pure_margin': ['100.1', '126.6', '104.3', '68']}
# {'company_name': '베스트바이 (BBY)', 'symbol': 'BBY', 'total_income': ['9910', '8562', '15196', '9764'], 'total_margine': ['2270', '1965', '3235', '2361'], 'salse_margin': ['568', '229', '967', '395'], 'pure_margin': ['432', '159', '745', '293']}
# {'company_name': 'Archer-Daniels-Midland Co (ADM)', 'symbol': 'ADM', 'total_income': ['16281', '14970', '16329', '16726'], 'total_margine': ['1108', '951', '1169', '1078'], 'salse_margin': ['454', '246', '412', '447'], 'pure_margin': ['469', '391', '504', '407']}
# {'company_name': '브라운 포먼 (BFb)', 'symbol': 'BFb', 'total_income': ['753', '709', '899', '989'], 'total_margine': ['465', '453', '557', '619'], 'salse_margin': ['387', '187', '304', '352'], 'pure_margin': ['324', '128', '231', '282']}
# {'company_name': 'IBM (IBM)', 'symbol': 'IBM', 'total_income': ['17560', '18123', '17571', '21777'], 'total_margine': ['8430', '8700', '7922', '11100'], 'salse_margin': ['1827', '1571', '-50', '3993'], 'pure_margin': ['1698', '1361', '1176', '3670']}
# {'company_name': '유니온 퍼시픽 (UNP)', 'symbol': 'UNP', 'total_income': ['4919', '4244', '5229', '5212'], 'total_margine': ['4110', '3556', '4274', '4169'], 'salse_margin': ['2031', '1654', '2143', '2098'], 'pure_margin': ['1363', '1132', '1474', '1403']}
# {'company_name': '마이크론 테크놀로지 (MU)', 'symbol': 'MU', 'total_income': ['6056', '5438', '4797', '5144'], 'total_margine': ['2068', '1763', '1355', '1366'], 'salse_margin': ['1157', '886', '440', '560'], 'pure_margin': ['988', '803', '405', '491']}
# {'company_name': 'Avery Dennison Corp (AVY)', 'symbol': 'AVY', 'total_income': ['1729.1', '1528.5', '1723', '1772.9'], 'total_margine': ['484.2', '382.9', '485.1', '484.7'], 'salse_margin': ['197.9', '103.5', '180.4', '165.2'], 'pure_margin': ['150.5', '79.7', '134.2', '162.5']}
# {'company_name': '마라톤 오일 (MRO)', 'symbol': 'MRO', 'total_income': ['274', '1221', '1221', '1323'], 'total_margine': ['145', '1061', '1052', '1160'], 'salse_margin': ['-703', '15', '70', '237'], 'pure_margin': ['-750', '-46', '-20', '165']}
# {'company_name': 'CF 인더스트리 (CF)', 'symbol': 'CF', 'total_income': ['1204', '971', '1049', '1038'], 'total_margine': ['334', '204', '227', '228'], 'salse_margin': ['280', '147', '154', '188'], 'pure_margin': ['190', '68', '55', '65']}
# {'company_name': '아파치 (APA)', 'symbol': 'APA', 'total_income': ['752', '1344', '1625', '1438'], 'total_margine': ['442', '923', '1282', '1088'], 'salse_margin': ['-154', '-4373', '-2986', '70'], 'pure_margin': ['-386', '-4480', '-2976', '-170']}
# {'company_name': '듀크 에너지 (DUK)', 'symbol': 'DUK', 'total_income': ['5421', '5949', '6103', '6940'], 'salse_margin': ['1177', '1488', '1109', '1929'], 'pure_margin': ['-802', '938', '674', '1342']}
# ...
# {'company_name': 'PVH - 필립스 반 호이젠 (PVH)', 'symbol': 'PVH', 'total_income': ['1580.7', '1344', '2600.8', '2587.7'], 'total_margine': ['883.3', '665.9', '1397.9', '1406.2'], 'salse_margin': ['-6.3', '-1214.7', '-95.7', '269.5'], 'pure_margin': ['-51.4', '-1096.8', '-67.4', '209.2']}
# {'company_name': 'Udr (UDR)', 'symbol': 'UDR', 'total_income': ['307.26', '321.48', '304.82', '295.39'], 'total_margine': ['204.73', '217.65', '208.61', '201.73'], 'salse_margin': ['91.78', '38.95', '44.78', '58.86'], 'pure_margin': ['57.77', '5.22', '97.64', '27.2']}
# {'company_name': '트립어드바이저 (TRIP)', 'symbol': 'TRIP', 'total_income': ['59', '278', '335', '428'], 'total_margine': ['49', '259', '314', '403'], 'salse_margin': ['-164', '-27', '23', '68'], 'pure_margin': ['-153', '-16', '16', '50']}
# {'company_name': 'SBA커뮤니케이션 (SBAC)', 'symbol': 'SBAC', 'total_income': ['507.23', '517.07', '513.66', '507.55'], 'total_margine': ['395.72', '401.55', '392.4', '384.04'], 'salse_margin': ['157.05', '134.34', '153.92', '153.39'], 'pure_margin': ['22.81', '-127.06', '67.35', '21.68']}
# {'company_name': '가트너 (IT)', 'symbol': 'IT', 'total_income': ['973.13', '1018.89', '1203.49', '1000.5'], 'total_margine': ['650.58', '677.61', '752.62', '635.45'], 'salse_margin': ['99.65', '124.72', '136.14', '69.15'], 'pure_margin': ['55.08', '75.1', '67.7', '41.39']}
# {'company_name': '유니버셜 헬스 서비스 (UHS)', 'symbol': 'UHS', 'total_income': ['2729.75', '2829.67', '2896.25', '2822.45'], 'total_margine': ['', '', '', ''], 'salse_margin': ['358.03', '236.69', '340.98', '188.93'], 'pure_margin': ['251.93', '142.04', '245.18', '97.19']}
# {'company_name': 'LKQ (LKQ)', 'symbol': 'LKQ', 'total_income': ['2626.32', '3000.93', '3009.86', '3147.77'], 'total_margine': ['1011', '1213.88', '1196.01', '1200.33'], 'salse_margin': ['180.45', '229.1', '206.9', '231.36'], 'pure_margin': ['118.79', '145.14', '140.39', '152.26']}
# {'company_name': '브로드리지 파이낸셜 솔루션즈 (BR)', 'symbol': 'BR', 'total_income': ['1361.9', '1249.9', '968.7', '948.6'], 'total_margine': ['477.7', '377.4', '187.8', '221.1'], 'salse_margin': ['298.8', '226.3', '26.8', '73.1'], 'pure_margin': ['229.7', '166.9', '10.1', '55.9']}
# {'company_name': '엑스트라 스페이스 (EXR)', 'symbol': 'EXR', 'total_income': ['327.25', '332.45', '335.8', '337.5'], 'total_margine': ['231.35', '235.48', '240.26', '241.21'], 'salse_margin': ['149.99', '157.19', '164.65', '162.64'], 'pure_margin': ['102.91', '108.18', '112.28', '108.09']}
# {'company_name': 'Mohawk Industries (MHK)', 'symbol': 'MHK', 'total_income': ['2049.8', '2285.76', '2424.51', '2519.18'], 'total_margine': ['420.01', '628.22', '665.18', '699.15'], 'salse_margin': ['-64.56', '151.48', '160.08', '175.05'], 'pure_margin': ['-48.26', '110.51', '264.67', '155.52']}
# {'company_name': '아메리칸워터웍스 (AWK)', 'symbol': 'AWK', 'total_income': ['931', '844', '902', '1013'], 'salse_margin': ['313', '239', '220', '406'], 'pure_margin': ['176', '124', '98', '240']}
# {'company_name': '얼라이언트 에너지 (LNT)', 'symbol': 'LNT', 'total_income': ['763.1', '915.7', '880.1', '990.2'], 'salse_margin': ['168.1', '188.3', '160.9', '290.2'], 'pure_margin': ['136.9', '172.6', '114', '228.6']}
# {'company_name': '헤인즈브랜즈 (HBI)', 'symbol': 'HBI', 'total_income': ['1738.78', '1316.46', '1751.01', '1866.97'], 'total_margine': ['659.55', '495.55', '729.99', '721.76'], 'salse_margin': ['241.54', '34.13', '237.92', '269.76'], 'pure_margin': ['161.18', '-7.87', '179.49', '187.78']}
# {'company_name': '셀라니즈 코퍼레이션 (CE)', 'symbol': 'CE', 'total_income': ['1193', '1460', '1432', '1586'], 'total_margine': ['242', '348', '316', '414'], 'salse_margin': ['83', '194', '68', '260'], 'pure_margin': ['107', '218', '43', '263']}
# {'company_name': '알래스카 항공 (ALK)', 'symbol': 'ALK', 'total_income': ['701', '421', '1636', '2228'], 'total_margine': ['230', '97', '748', '1259'], 'salse_margin': ['-571', '-288', '-321', '252'], 'pure_margin': ['-431', '-214', '-232', '181']}
# {'company_name': '아메텍 (AME)', 'symbol': 'AME', 'total_income': ['1011.92', '1202.22', '1304.82', '1276.63'], 'total_margine': ['342.73', '421.27', '446.65', '453.37'], 'salse_margin': ['226.99', '373.04', '297.65', '301.06'], 'pure_margin': ['166.22', '280.62', '220.78', '220.75']}
# {'company_name': '리온델바셀 인더스트리즈 (LYB)', 'symbol': 'LYB', 'total_income': ['5546', '7494', '8179', '8722'], 'total_margine': ['652', '629', '1151', '1452'], 'salse_margin': ['339', '304', '798', '1124'], 'pure_margin': ['314', '144', '612', '965']}
# {'company_name': '로얄 캐리비안 (RCL)', 'symbol': 'RCL', 'total_income': ['175.6', '2032.75', '2517.41', '3186.85'], 'total_margine': ['-479.2', '543.68', '1062.03', '1589.8'], 'salse_margin': ['-1282.49', '-1306.41', '299.43', '890.79'], 'pure_margin': ['-1639.29', '-1444.48', '273.14', '883.24']}
# {'company_name': '플리코 테크놀로지스 (FLT)', 'symbol': 'FLT', 'total_income': ['525.15', '661.09', '698.88', '681.05'], 'total_margine': ['', '', '698.88', ''], 'salse_margin': ['212.81', '200.98', '320.8', '329.14'], 'pure_margin': ['158.49', '147.06', '235.51', '225.81']}
# {'company_name': '패키징 코퍼레이션 오브 아메리카 (PKG)', 'symbol': 'PKG', 'total_income': ['1541.6', '1708.7', '1720', '1750.7'], 'total_margine': ['331.9', '365.8', '383.3', '411.4'], 'salse_margin': ['116.1', '209.1', '235.1', '262.8'], 'pure_margin': ['56.7', '141.7', '136.2', '179.8']}
# {'company_name': 'Arthur J. Gallagher & Co (AJG)', 'symbol': 'AJG', 'total_income': ['1584', '1866.9', '1721.4', '1825.2'], 'total_margine': ['574.8', '747.6', '545.3', '554.4'], 'salse_margin': ['226.8', '418.9', '132.1', '161.4'], 'pure_margin': ['153.7', '346.3', '98.5', '126.1']}
# {'company_name': '처치앤드와이트 (CHD)', 'symbol': 'CHD', 'total_income': ['1194.3', '1165.2', '1144.2', '1089.4'], 'total_margine': ['559.6', '532', '524', '507.7'], 'salse_margin': ['250.7', '314.6', '195.2', '216.8'], 'pure_margin': ['189.7', '229.8', '144.4', '157.3']}
# {'company_name': '글로벌 페이먼트 (GPN)', 'symbol': 'GPN', 'total_income': ['1671.95', '1903.6', '1987.76', '1105.94'], 'total_margine': ['778.21', '969.73', '958.68', '681.22'], 'salse_margin': ['107.57', '243.98', '196.16', '174.04'], 'pure_margin': ['37.33', '143.57', '102.77', '95.04']}
# {'company_name': '홀리프런티어 (HFC)', 'symbol': 'HFC', 'total_income': ['2062.93', '3400.55', '4381.89', '4424.83'], 'total_margine': ['755.84', '173.27', '771.94', '972.33'], 'salse_margin': ['-189.98', '-436.22', '129.18', '426.78'], 'pure_margin': ['-176.68', '-304.62', '60.6', '261.81']}
# {'company_name': '리얼티인컴 (O)', 'symbol': 'O', 'total_income': ['414.64', '414.34', '397.53', '374.25'], 'total_margine': ['388.18', '388.74', '372.28', '353.89'], 'salse_margin': ['110.03', '113.91', '116.29', '102.05'], 'pure_margin': ['107.82', '146.83', '129.3', '101.05']}
# {'company_name': 'A.O 스미스 (AOS)', 'symbol': 'AOS', 'total_income': ['663.9', '636.9', '750.9', '728.2'], 'total_margine': ['247.5', '239.5', '295', '284.2'], 'salse_margin': ['87', '67.7', '115.5', '112.8'], 'pure_margin': ['67.8', '51.7', '91.3', '87.3']}
# {'company_name': 'Fortune Brands Home & Security (FBHS)', 'symbol': 'FBHS', 'total_income': ['1375.8', '1402.7', '1470.5', '1459'], 'total_margine': ['482.9', '493.2', '535.9', '524.2'], 'salse_margin': ['173', '155', '192.5', '168'], 'pure_margin': ['115.8', '109.1', '104.1', '105.6']}
# {'company_name': 'Cboe Global Markets Inc (CBOE)', 'symbol': 'CBOE', 'total_income': ['868.7', '921.5', '598.6', '675.4'], 'total_margine': ['296.9', '358.3', '280.3', '294'], 'salse_margin': ['161.7', '226.4', '119.2', '147.4'], 'pure_margin': ['113.6', '157.4', '86.3', '106']}
# {'company_name': '코파츠 (CPRT)', 'symbol': 'CPRT', 'total_income': ['525.66', '550.36', '575.14', '554.42'], 'total_margine': ['250.43', '242.61', '259.89', '254.87'], 'salse_margin': ['205.72', '195.1', '209.89', '205.39'], 'pure_margin': ['165.53', '147.49', '168.71', '218.18']}
# {'company_name': '시놉시스 (SNPS)', 'symbol': 'SNPS', 'total_income': ['964.13', '861.33', '834.38', '851.08'], 'total_margine': ['771.13', '677.06', '641.51', '668.34'], 'salse_margin': ['210.6', '125.89', '87.52', '129.72'], 'pure_margin': ['252.91', '109.92', '104.06', '160.71']}
# {'company_name': '울타 뷰티 (ULTA)', 'symbol': 'ULTA', 'total_income': ['1228.01', '1173.21', '2305.92', '1682.51'], 'total_margine': ['329.01', '303.61', '806.88', '623.43'], 'salse_margin': ['12.76', '-101.48', '287.76', '167.78'], 'pure_margin': ['8.05', '-78.51', '222.72', '129.75']}
# {'company_name': '베리스크 어낼리틱스 (VRSK)', 'symbol': 'VRSK', 'total_income': ['678.8', '689.8', '676.8', '652.7'], 'total_margine': ['443', '432.1', '417', '409.8'], 'salse_margin': ['259.7', '252.3', '200.4', '75.7'], 'pure_margin': ['179', '171.7', '132.2', '32.9']}
# {'company_name': '애브비 (ABBV)', 'symbol': 'ABBV', 'total_income': ['10425', '8619', '8704', '8479'], 'total_margine': ['6714', '6677', '6650', '6517'], 'salse_margin': ['752', '3603', '3956', '2617'], 'pure_margin': ['-738', '3010', '2801', '1884']}
# {'company_name': '다이아몬드백 에너지 (FANG)', 'symbol': 'FANG', 'total_income': ['425', '899', '1104', '975'], 'total_margine': ['232', '642', '845', '735'], 'salse_margin': ['-2675', '-802', '-440', '349'], 'pure_margin': ['-2393', '-272', '-487', '368']}
# {'company_name': '노르웨이안 크루즈 홀딩스 (NCLH)', 'symbol': 'NCLH', 'total_income': ['16.93', '1246.88', '1480.62', '1913.85'], 'total_margine': ['-284.72', '252.62', '593.2', '923.09'], 'salse_margin': ['-574.25', '-1824.06', '189.97', '511.72'], 'pure_margin': ['-715.24', '-1880.97', '121.3', '450.58']}
# {'company_name': '조에티스 (ZTS)', 'symbol': 'ZTS', 'total_income': ['1548', '1534', '1674', '1584'], 'total_margine': ['1102', '1076', '1148', '1109'], 'salse_margin': ['482', '497', '437', '528'], 'pure_margin': ['377', '423', '384', '433']}
# {'company_name': '아이큐비아 (IQV)', 'symbol': 'IQV', 'total_income': ['2521', '2754', '2895', '2769'], 'total_margine': ['817', '930', '994', '917'], 'salse_margin': ['50', '193', '166', '180'], 'pure_margin': ['-23', '82', '16', '57']}
# {'company_name': '코티 (COTY)', 'symbol': 'COTY', 'total_income': ['560.4', '4157.4', '2345', '1942.8'], 'total_margine': ['227.5', '2513.6', '1485.7', '1204.4'], 'salse_margin': ['-920.5', '-316', '35.4', '126'], 'pure_margin': ['-766.3', '-240.4', '-21.1', '52.3']}
# {'company_name': '트위터 (TWTR)', 'symbol': 'TWTR', 'total_income': ['683.44', '807.64', '1007.34', '823.72'], 'total_margine': ['395.4', '523.6', '693.33', '542.66'], 'salse_margin': ['-274.43', '-15.44', '152.88', '44.15'], 'pure_margin': ['-1378.01', '-8.4', '118.77', '36.52']}
# {'company_name': '힐튼 월드와이드 (HLT)', 'symbol': 'HLT', 'total_income': ['564', '1920', '2369', '2395'], 'total_margine': ['10', '584', '890', '952'], 'salse_margin': ['-302', '68', '348', '519'], 'pure_margin': ['-430', '18', '175', '288']}
# {'company_name': '아메리칸항공그룹 (AAL)', 'symbol': 'AAL', 'total_income': ['3173', '1622', '8515', '11313'], 'total_margine': ['1102', '35', '4672', '6957'], 'salse_margin': ['-2871', '-2486', '-2549', '729'], 'pure_margin': ['-2399', '-2067', '-2241', '414']}
# {'company_name': '얼리전 (ALLE)', 'symbol': 'ALLE', 'total_income': ['728.4', '589.5', '674.7', '719.5'], 'total_margine': ['321.1', '248.9', '293.1', '319.2'], 'salse_margin': ['160.4', '96.5', '28.9', '113.2'], 'pure_margin': ['146.9', '73.7', '0.4', '80.7']}
# {'company_name': '알파벳 C (GOOG)', 'symbol': 'GOOG', 'total_income': ['38297', '41159', '46075', '40499'], 'total_margine': ['19744', '22177', '25055', '22931'], 'salse_margin': ['6383', '7977', '9266', '9177'], 'pure_margin': ['6959', '6836', '10671', '7068']}
# {'company_name': 'IHS마르키트 (INFO)', 'symbol': 'INFO', 'total_income': ['1073.2', '1026.6', '1080.8', '1120.4'], 'total_margine': ['687.6', '638.3', '665', '710.9'], 'salse_margin': ['261.2', '144.1', '570.9', '247'], 'pure_margin': ['162.9', '71.7', '485', '203.1']}
# {'company_name': '아리스타 네트웍스 (ANET)', 'symbol': 'ANET', 'total_income': ['540.57', '523.03', '552.55', '654.41'], 'total_margine': ['344.09', '338.25', '356.3', '417.27'], 'salse_margin': ['166.99', '149.66', '175.99', '228.61'], 'pure_margin': ['144.79', '138.43', '260.69', '208.9']}
# {'company_name': '싱크로니 파이낸셜 (SYF)', 'symbol': 'SYF', 'total_income': ['3968', '3925', '4504', '4689'], 'pure_margin': ['313', '48', '286', '731']}
# {'company_name': '시티즌 금융 그룹 (CFG)', 'symbol': 'CFG', 'total_income': ['1934', '1940', '1975', '1995'], 'pure_margin': ['314', '253', '34', '450']}
# {'company_name': '키사이트 테크놀로지 (KEYS)', 'symbol': 'KEYS', 'total_income': ['1011', '895', '1095', '1120'], 'total_margine': ['606', '516', '655', '665'], 'salse_margin': ['182', '102', '203', '208'], 'pure_margin': ['176', '71', '163', '195']}
# {'company_name': '코르보 (QRVO)', 'symbol': 'QRVO', 'total_income': ['787.45', '787.77', '869.07', '806.7'], 'total_margine': ['325.79', '338.06', '375.87', '330.19'], 'salse_margin': ['92.71', '95.95', '151.27', '63.97'], 'pure_margin': ['96.92', '50.39', '161.36', '83.04']}
# {'company_name': '웨스트록 (WRK)', 'symbol': 'WRK', 'total_income': ['4236.3', '4447.3', '4423.7', '4651.6'], 'total_margine': ['770', '804.8', '809', '1078.7'], 'salse_margin': ['271', '273.9', '252.7', '489.9'], 'pure_margin': ['178.5', '148.1', '138.5', '310.8']}
# {'company_name': '페이팔 홀딩스 (PYPL)', 'symbol': 'PYPL', 'total_income': ['5261', '4618', '4961', '4378'], 'total_margine': ['2555', '1889', '2229', '1947'], 'salse_margin': ['951', '398', '799', '697'], 'pure_margin': ['1530', '84', '507', '462']}
# {'company_name': '휴렛패커드 엔터프라이즈 (HPE)', 'symbol': 'HPE', 'total_income': ['6816', '6009', '6949', '7215'], 'total_margine': ['2067', '1914', '2282', '2393'], 'salse_margin': ['-18', '-869', '327', '748'], 'pure_margin': ['9', '-821', '333', '480']}
# {'company_name': '언더아머 C (UA)', 'symbol': 'UA', 'total_income': ['707.64', '930.24', '1441.22', '1429.46'], 'total_margine': ['349.17', '430.98', '681.53', '689.9'], 'salse_margin': ['-169.67', '-558.18', '74.07', '138.92'], 'pure_margin': ['-182.9', '-589.68', '-15.3', '102.31']}
# {'company_name': '포티브 코퍼레이션 (FTV)', 'symbol': 'FTV', 'total_income': ['1571.2', '1713.5', '2002.4', '1860'], 'total_margine': ['814.3', '875.8', '1035.9', '927.7'], 'salse_margin': ['191.1', '119.6', '294.8', '283.3'], 'pure_margin': ['130', '41.9', '192.8', '207.1']}
# {'company_name': '알코닉 (ARNC)', 'symbol': 'ARNC', 'total_income': ['1187', '1611', '1708', '3559'], 'total_margine': ['141', '284', '248', '759'], 'salse_margin': ['-67', '152', '101', '326'], 'pure_margin': ['-92', '60', '186', '95']}
# {'company_name': '램웨스턴 (LW)', 'symbol': 'LW', 'total_income': ['871.5', '846.9', '937.3', '1019.2'], 'total_margine': ['213.8', '111.1', '250.4', '285.1'], 'salse_margin': ['135.7', '30.9', '162.5', '193.5'], 'pure_margin': ['89.3', '-1.6', '111.4', '140.4']}
# {'company_name': '폭스 코퍼레이션 (FOXA)', 'symbol': 'FOXA', 'total_income': ['2418', '3440', '3778', '2667'], 'total_margine': ['1231', '1379', '687', '1199'], 'salse_margin': ['120', '811', '170', '743'], 'pure_margin': ['122', '78', '300', '499']}
# {'company_name': '폭스 B (FOX)', 'symbol': 'FOX', 'total_income': ['2418', '3440', '3778', '2667'], 'total_margine': ['1231', '1379', '687', '1199'], 'salse_margin': ['120', '811', '170', '743'], 'pure_margin': ['122', '78', '300', '499']}
# {'company_name': '코르테바 (CTVA)', 'symbol': 'CTVA', 'total_income': ['5191', '3956', '2983', '1911'], 'total_margine': ['2362', '1687', '1015', '562'], 'salse_margin': ['785', '371', '-215', '-669'], 'pure_margin': ['760', '272', '-21', '-494']}
# {'company_name': '암코 (AMCR)', 'symbol': 'AMCR', 'total_income': ['3142.7', '3141', '3043.1', '3140.7'], 'total_margine': ['719.5', '652', '617.3', '546.7'], 'salse_margin': ['309.9', '271.2', '272.3', '140.6'], 'pure_margin': ['179.1', '181.5', '185.6', '66']}
# {'company_name': '린드 (LINI)', 'symbol': 'LINI', 'total_income': ['6377', '6739', '7080', '7000'], 'total_margine': ['2758', '2896', '2893', '2939'], 'salse_margin': ['591', '733', '655', '1000'], 'pure_margin': ['458', '573', '511', '735']}
